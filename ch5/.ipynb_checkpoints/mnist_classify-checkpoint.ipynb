# %%
import tensorflow as tf
from matplotlib import pylab
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np

# Required for Data downaload and preparation
import struct
import gzip
import os
from six.moves.urllib.request import urlretrieve
# Out:
# C:\Peter\Anaconda36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X)//batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches): #把rnd_idx分割成n_batches個陣列，每個為batch_size(50)大小
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
from __future__ import division, print_function, unicode_literals
from io import open

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "cnn"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %% [markdown]
# ## Lolading Data
#
# Here we download (if needed) the MNIST dataset and, perform reshaping and normalization. Also we conver the labels to one hot encoded vectors.

# %% [markdown]
# batch_size = 100 # This is the typical batch size we've been using
# image_size = 28 # This is the width/height of a single image
#
# # Number of color channels in an image. These are black and white images
# n_channels = 1
#
# # Number of different digits we have images for (i.e. classes)
# n_classes = 10
#
# n_train = 55000 # Train dataset size
# n_valid = 5000 # Validation dataset size
# n_test = 10000 # Test dataset size
#
# def maybe_download(url, filename, expected_bytes, force=False):
#   """Download a file if not present, and make sure it's the right size."""
#   if force or not os.path.exists(filename):
#     print('Attempting to download:', filename)
#     filename, _ = urlretrieve(url + filename, filename)
#     print('\nDownload Complete!')
#   statinfo = os.stat(filename)
#   if statinfo.st_size == expected_bytes:
#     print('Found and verified', filename)
#   else:
#     raise Exception(
#       'Failed to verify ' + filename +\
#         '. Can you get to it with a browser?')
#   return filename
#
#
# def read_mnist(fname_img, fname_lbl, one_hot=True):
#     print('\nReading files %s and %s'%(fname_img, fname_lbl))
#
#     # Processing images
#     with gzip.open(fname_img) as fimg:
#         magic, num, rows, cols = struct.unpack(">IIII", fimg.read(16))
#         print(num,rows,cols)
#         img = (np.frombuffer(fimg.read(num*rows*cols),\
#                  dtype=np.uint8).reshape(num, rows, cols,1)).\
#                  astype(np.float32)
#         print('(Images) Returned a tensor of shape ',img.shape)
#
#         img = (img - np.mean(img)) /np.std(img)
#         #img *= 1.0 / 255.0
#
#     # Processing labels
#     with gzip.open(fname_lbl) as flbl:
#         # flbl.read(8) reads upto 8 bytes
#         magic, num = struct.unpack(">II", flbl.read(8))
#         lbl = np.frombuffer(flbl.read(num), dtype=np.int8)
#         if one_hot:
#             one_hot_lbl = np.zeros(shape=(num,10),dtype=np.float32)
#             one_hot_lbl[np.arange(num),lbl] = 1.0
#         print('(Labels) Returned a tensor of shape: %s'%lbl.shape)
#         print('Sample labels: ',lbl[:10])
#
#     if  one_hot:
#         return img, one_hot_lbl
#     else:
#         return img, lbl

# %% [markdown]
# train_inputs, train_labels = read_mnist(\
#                             'train-images-idx3-ubyte.gz',\
#                             'train-labels-idx1-ubyte.gz',one_hot= False)
# print('train_input Shape: ', train_inputs.shape)
# print('train_labels Shape: ', train_labels.shape)
# X_train, y_train = train_inputs[:n_train,:,:,:], train_labels[:n_train]
# X_valid, y_valid = train_inputs[n_train:,:,:,:], train_labels[n_train:]
# print()
# print('Train Inputs Shape: ', X_train.shape)
# print('X_train[:5]', X_train[:5, 10:18, 5:10, 0])
# print('Train labels Shape: ', y_train.shape)
# print('y_train[:5]', y_train[:5])
# print('Valid Inputs Shape: ', X_valid.shape)
# print('X_valid[:5]', X_valid[:3, 10:18, 5:10, 0])
# print('Valid labels Shape: ', y_valid.shape)
# print('y_train[:5]', y_train[:5])
#
# X_test, y_test = read_mnist('t10k-images-idx3-ubyte.gz',\
#                             't10k-labels-idx1-ubyte.gz',one_hot=False)
# print()
# print('Test Inputs Shape: ' , X_test.shape)
# print('Train labels Shape: ', y_test.shape)

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
height = 28
width = 28
channels = 1
n_inputs = height * width

conv1_fmaps = 32
conv1_ksize = 3
conv1_stride = 1
conv1_pad = "SAME"

conv2_fmaps = 64
conv2_ksize = 3
conv2_stride = 2
conv2_pad = "SAME"

pool3_fmaps = conv2_fmaps

n_fc1 = 64
n_outputs = 10

reset_graph()

with tf.name_scope("inputs"):
    X = tf.placeholder(tf.float32, shape=[None, n_inputs], name="X")
    X_reshaped = tf.reshape(X, shape=[-1, height, width, channels])
    y = tf.placeholder(tf.int32, shape=[None], name="y")

conv1 = tf.layers.conv2d(X_reshaped, filters=conv1_fmaps, kernel_size=conv1_ksize,
                         strides=conv1_stride, padding=conv1_pad,
                         activation=tf.nn.relu, name="conv1")
conv2 = tf.layers.conv2d(conv1, filters=conv2_fmaps, kernel_size=conv2_ksize,
                         strides=conv2_stride, padding=conv2_pad,
                         activation=tf.nn.relu, name="conv2")

with tf.name_scope("pool3"):
    pool3 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding="VALID")
    pool3_flat = tf.reshape(pool3, shape=[-1, pool3_fmaps * 7 * 7])

with tf.name_scope("fc1"):
    fc1 = tf.layers.dense(pool3_flat, n_fc1, activation=tf.nn.relu, name="fc1")

with tf.name_scope("output"):
    logits = tf.layers.dense(fc1, n_outputs, name="output")
    Y_proba = tf.nn.softmax(logits, name="Y_proba")

with tf.name_scope("train"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y)
    loss = tf.reduce_mean(xentropy)
    optimizer = tf.train.AdamOptimizer()
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

with tf.name_scope("init_and_save"):
    init = tf.global_variables_initializer()
    saver = tf.train.Saver()

# %% [markdown]
# height = 28
# width = 28
# channels = 1
# n_inputs = height * width
#
# conv1_fmaps = 32
# conv1_ksize = 3
# conv1_stride = 1
# conv1_pad = "SAME"
#
# conv2_fmaps = 64
# conv2_ksize = 3
# conv2_stride = 2
# conv2_pad = "SAME"
#
# pool3_fmaps = conv2_fmaps
#
# n_fc1 = 64
# n_outputs = 10
#
# reset_graph()
#
# with tf.name_scope("inputs"):
#     X = tf.placeholder(tf.float32,\
#            shape=(None,height,width,channels),name="X")
#
#     #X_reshaped = tf.reshape(X, shape=[-1, height, width, channels])
#     y = tf.placeholder(tf.int32, shape=(None), name="y")
#
# conv1 = tf.layers.conv2d(X, filters=conv1_fmaps,\
#                          kernel_size=conv1_ksize,
#                          strides=conv1_stride, padding=conv1_pad,
#                          activation=tf.nn.relu, name="conv1")
# conv2 = tf.layers.conv2d(conv1, filters=conv2_fmaps,\
#                          kernel_size=conv2_ksize,
#                          strides=conv2_stride, padding=conv2_pad,
#                          activation=tf.nn.relu, name="conv2")
#
# with tf.name_scope("pool3"):
#     pool3 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1],\
#                            strides=[1, 2, 2, 1], padding="VALID")
#     pool3_flat = tf.reshape(pool3, shape=[-1, pool3_fmaps * 7 * 7])
#
# with tf.name_scope("fc1"):
#     fc1 = tf.layers.dense(pool3_flat, n_fc1,\
#                           activation=tf.nn.relu, name="fc1")
#
# with tf.name_scope("output"):
#     logits = tf.layers.dense(fc1, n_outputs, name="output")
#     Y_proba = tf.nn.softmax(logits, name="Y_proba")
#
# with tf.name_scope("train"):
#     xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(\
#                       logits=logits, labels=y)
#     loss = tf.reduce_mean(xentropy)
#     optimizer = tf.train.AdamOptimizer()
#     training_op = optimizer.minimize(loss)
#
# with tf.name_scope("eval"):
#     correct = tf.nn.in_top_k(logits, y, 1)
#     accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
#
# with tf.name_scope("init_and_save"):
#     init = tf.global_variables_initializer()
#     saver = tf.train.Saver()

# %%
n_epochs = 10
batch_size = 100

max_checks_without_progress = 20
checks_without_progress = 0
best_loss = np.infty

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        i = 0
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
            #i += 1
            #print(i,' X_batch.shape', X_batch.shape)
        print('epoch ',epoch)
        acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print(epoch, "Last batch accuracy:", acc_batch, "Test accuracy:", acc_test)

        '''loss_val = sess.run(loss, feed_dict={X: X_valid, y: y_valid})        
        #loss_val, acc_val = sess.run([loss, accuracy], feed_dict={X: X_valid, y: y_valid})
        if loss_val < best_loss:
            save_path = saver.save(sess, "./mnist_model.ckpt")
            best_loss = loss_val
            checks_without_progress = 0
        else:
            checks_without_progress += 1
            if checks_without_progress > max_checks_without_progress:
                print("Early stopping!")
                break
        print("{}\tValidation loss: {:.6f}\tBest loss:\
                {:.6f}\tAccuracy: {:.2f}%".format(\
                epoch, loss_val, best_loss, acc_val * 100))
        
    save_path = saver.save(sess, "./mnist_model")
        
with tf.Session() as sess:
    #saver.restore(sess, "./mnist_model.ckpt")
    acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
    print("Final test accuracy: {:.2f}%".format(acc_test * 100))
'''
# Out:
# 1  X_batch.shape (100, 784)
# 2  X_batch.shape (100, 784)
# 3  X_batch.shape (100, 784)
# 4  X_batch.shape (100, 784)
# 5  X_batch.shape (100, 784)
# 6  X_batch.shape (100, 784)
# 7  X_batch.shape (100, 784)
# 8  X_batch.shape (100, 784)
# 9  X_batch.shape (100, 784)
# 10  X_batch.shape (100, 784)
# 11  X_batch.shape (100, 784)
# 12  X_batch.shape (100, 784)
# 13  X_batch.shape (100, 784)
# 14  X_batch.shape (100, 784)
# 15  X_batch.shape (100, 784)
# 16  X_batch.shape (100, 784)
# 17  X_batch.shape (100, 784)
# 18  X_batch.shape (100, 784)
# 19  X_batch.shape (100, 784)
# 20  X_batch.shape (100, 784)
# 21  X_batch.shape (100, 784)
# 22  X_batch.shape (100, 784)
# 23  X_batch.shape (100, 784)
# 24  X_batch.shape (100, 784)
# 25  X_batch.shape (100, 784)
# 26  X_batch.shape (100, 784)
# 27  X_batch.shape (100, 784)
# 28  X_batch.shape (100, 784)
# 29  X_batch.shape (100, 784)
# 30  X_batch.shape (100, 784)
# 31  X_batch.shape (100, 784)
# 32  X_batch.shape (100, 784)
# 33  X_batch.shape (100, 784)
# 34  X_batch.shape (100, 784)
# 35  X_batch.shape (100, 784)
# 36  X_batch.shape (100, 784)
# 37  X_batch.shape (100, 784)
# 38  X_batch.shape (100, 784)
# 39  X_batch.shape (100, 784)
# 40  X_batch.shape (100, 784)
# 41  X_batch.shape (100, 784)
# 42  X_batch.shape (100, 784)
# 43  X_batch.shape (100, 784)
# 44  X_batch.shape (100, 784)
# 45  X_batch.shape (100, 784)
# 46  X_batch.shape (100, 784)
# 47  X_batch.shape (100, 784)
# 48  X_batch.shape (100, 784)
# 49  X_batch.shape (100, 784)
# 50  X_batch.shape (100, 784)
# 51  X_batch.shape (100, 784)
# 52  X_batch.shape (100, 784)
# 53  X_batch.shape (100, 784)
# 54  X_batch.shape (100, 784)
# 55  X_batch.shape (100, 784)
# 56  X_batch.shape (100, 784)
# 57  X_batch.shape (100, 784)
# 58  X_batch.shape (100, 784)
# 59  X_batch.shape (100, 784)
# 60  X_batch.shape (100, 784)
# 61  X_batch.shape (100, 784)
# 62  X_batch.shape (100, 784)
# 63  X_batch.shape (100, 784)
# 64  X_batch.shape (100, 784)
# 65  X_batch.shape (100, 784)
# 66  X_batch.shape (100, 784)
# 67  X_batch.shape (100, 784)
# 68  X_batch.shape (100, 784)
# 69  X_batch.shape (100, 784)
# 70  X_batch.shape (100, 784)
# 71  X_batch.shape (100, 784)
# 72  X_batch.shape (100, 784)
# 73  X_batch.shape (100, 784)
# 74  X_batch.shape (100, 784)
# 75  X_batch.shape (100, 784)
# 76  X_batch.shape (100, 784)
# 77  X_batch.shape (100, 784)
# 78  X_batch.shape (100, 784)
# 79  X_batch.shape (100, 784)
# 80  X_batch.shape (100, 784)
# 81  X_batch.shape (100, 784)
# 82  X_batch.shape (100, 784)
# 83  X_batch.shape (100, 784)
# 84  X_batch.shape (100, 784)
# 85  X_batch.shape (100, 784)
# 86  X_batch.shape (100, 784)
# 87  X_batch.shape (100, 784)
# 88  X_batch.shape (100, 784)
# 89  X_batch.shape (100, 784)
# 90  X_batch.shape (100, 784)
# 91  X_batch.shape (100, 784)
# 92  X_batch.shape (100, 784)
# 93  X_batch.shape (100, 784)
# 94  X_batch.shape (100, 784)
# 95  X_batch.shape (100, 784)
# 96  X_batch.shape (100, 784)
# 97  X_batch.shape (100, 784)
# 98  X_batch.shape (100, 784)
# 99  X_batch.shape (100, 784)
# 100  X_batch.shape (100, 784)
# 101  X_batch.shape (100, 784)
# 102  X_batch.shape (100, 784)
# 103  X_batch.shape (100, 784)
# 104  X_batch.shape (100, 784)
# 105  X_batch.shape (100, 784)
# 106  X_batch.shape (100, 784)
# 107  X_batch.shape (100, 784)
# 108  X_batch.shape (100, 784)
# 109  X_batch.shape (100, 784)
# 110  X_batch.shape (100, 784)
# 111  X_batch.shape (100, 784)
# 112  X_batch.shape (100, 784)
# 113  X_batch.shape (100, 784)
# 114  X_batch.shape (100, 784)
# 115  X_batch.shape (100, 784)
# 116  X_batch.shape (100, 784)
# 117  X_batch.shape (100, 784)
# 118  X_batch.shape (100, 784)
# 119  X_batch.shape (100, 784)
# 120  X_batch.shape (100, 784)
# 121  X_batch.shape (100, 784)
# 122  X_batch.shape (100, 784)
# 123  X_batch.shape (100, 784)
# 124  X_batch.shape (100, 784)
# 125  X_batch.shape (100, 784)
# 126  X_batch.shape (100, 784)
# 127  X_batch.shape (100, 784)
# 128  X_batch.shape (100, 784)
# 129  X_batch.shape (100, 784)
# 130  X_batch.shape (100, 784)
# 131  X_batch.shape (100, 784)
# 132  X_batch.shape (100, 784)
# 133  X_batch.shape (100, 784)
# 134  X_batch.shape (100, 784)
# 135  X_batch.shape (100, 784)
# 136  X_batch.shape (100, 784)
# 137  X_batch.shape (100, 784)
# 138  X_batch.shape (100, 784)
# 139  X_batch.shape (100, 784)
# 140  X_batch.shape (100, 784)
# 141  X_batch.shape (100, 784)
# 142  X_batch.shape (100, 784)
# 143  X_batch.shape (100, 784)
# 144  X_batch.shape (100, 784)
# 145  X_batch.shape (100, 784)
# 146  X_batch.shape (100, 784)
# 147  X_batch.shape (100, 784)
# 148  X_batch.shape (100, 784)
# 149  X_batch.shape (100, 784)
# 150  X_batch.shape (100, 784)
# 151  X_batch.shape (100, 784)
# 152  X_batch.shape (100, 784)
# 153  X_batch.shape (100, 784)
# 154  X_batch.shape (100, 784)
# 155  X_batch.shape (100, 784)
# 156  X_batch.shape (100, 784)
# 157  X_batch.shape (100, 784)
# 158  X_batch.shape (100, 784)
# 159  X_batch.shape (100, 784)
# 160  X_batch.shape (100, 784)
# 161  X_batch.shape (100, 784)
# 162  X_batch.shape (100, 784)
# 163  X_batch.shape (100, 784)
# 164  X_batch.shape (100, 784)
# 165  X_batch.shape (100, 784)
# 166  X_batch.shape (100, 784)
# 167  X_batch.shape (100, 784)
# 168  X_batch.shape (100, 784)
# 169  X_batch.shape (100, 784)
# 170  X_batch.shape (100, 784)
# 171  X_batch.shape (100, 784)
# 172  X_batch.shape (100, 784)
# 173  X_batch.shape (100, 784)
# 174  X_batch.shape (100, 784)
# 175  X_batch.shape (100, 784)
# 176  X_batch.shape (100, 784)
# 177  X_batch.shape (100, 784)
# 178  X_batch.shape (100, 784)
# 179  X_batch.shape (100, 784)
# 180  X_batch.shape (100, 784)
# 181  X_batch.shape (100, 784)
# 182  X_batch.shape (100, 784)
# 183  X_batch.shape (100, 784)
# 184  X_batch.shape (100, 784)
# 185  X_batch.shape (100, 784)
# 186  X_batch.shape (100, 784)
# 187  X_batch.shape (100, 784)
# 188  X_batch.shape (100, 784)
# 189  X_batch.shape (100, 784)
# 190  X_batch.shape (100, 784)
# 191  X_batch.shape (100, 784)
# 192  X_batch.shape (100, 784)
# 193  X_batch.shape (100, 784)
# 194  X_batch.shape (100, 784)
# 195  X_batch.shape (100, 784)
# 196  X_batch.shape (100, 784)
# 197  X_batch.shape (100, 784)
# 198  X_batch.shape (100, 784)
# 199  X_batch.shape (100, 784)
# 200  X_batch.shape (100, 784)
# 201  X_batch.shape (100, 784)
# 202  X_batch.shape (100, 784)
# 203  X_batch.shape (100, 784)
# 204  X_batch.shape (100, 784)
# 205  X_batch.shape (100, 784)
# 206  X_batch.shape (100, 784)
# 207  X_batch.shape (100, 784)
# 208  X_batch.shape (100, 784)
# 209  X_batch.shape (100, 784)
# 210  X_batch.shape (100, 784)
# 211  X_batch.shape (100, 784)
# 212  X_batch.shape (100, 784)
# 213  X_batch.shape (100, 784)
# 214  X_batch.shape (100, 784)
# 215  X_batch.shape (100, 784)
# 216  X_batch.shape (100, 784)
# 217  X_batch.shape (100, 784)
# 218  X_batch.shape (100, 784)
# 219  X_batch.shape (100, 784)
# 220  X_batch.shape (100, 784)
# 221  X_batch.shape (100, 784)
# 222  X_batch.shape (100, 784)
# 223  X_batch.shape (100, 784)
# 224  X_batch.shape (100, 784)
# 225  X_batch.shape (100, 784)
# 226  X_batch.shape (100, 784)
# 227  X_batch.shape (100, 784)
# 228  X_batch.shape (100, 784)
# 229  X_batch.shape (100, 784)
# 230  X_batch.shape (100, 784)
# 231  X_batch.shape (100, 784)
# 232  X_batch.shape (100, 784)
# 233  X_batch.shape (100, 784)
# 234  X_batch.shape (100, 784)
# 235  X_batch.shape (100, 784)
# 236  X_batch.shape (100, 784)
# 237  X_batch.shape (100, 784)
# 238  X_batch.shape (100, 784)
# 239  X_batch.shape (100, 784)
# 240  X_batch.shape (100, 784)
# 241  X_batch.shape (100, 784)
# 242  X_batch.shape (100, 784)
# 243  X_batch.shape (100, 784)
# 244  X_batch.shape (100, 784)
# 245  X_batch.shape (100, 784)
# 246  X_batch.shape (100, 784)
# 247  X_batch.shape (100, 784)
# 248  X_batch.shape (100, 784)
# 249  X_batch.shape (100, 784)
# 250  X_batch.shape (100, 784)
# 251  X_batch.shape (100, 784)
# 252  X_batch.shape (100, 784)
# 253  X_batch.shape (100, 784)
# 254  X_batch.shape (100, 784)
# 255  X_batch.shape (100, 784)
# 256  X_batch.shape (100, 784)
# 257  X_batch.shape (100, 784)
# 258  X_batch.shape (100, 784)
# 259  X_batch.shape (100, 784)
# 260  X_batch.shape (100, 784)
# 261  X_batch.shape (100, 784)
# 262  X_batch.shape (100, 784)
# 263  X_batch.shape (100, 784)
# 264  X_batch.shape (100, 784)
# 265  X_batch.shape (100, 784)
# 266  X_batch.shape (100, 784)
# 267  X_batch.shape (100, 784)
# 268  X_batch.shape (100, 784)
# 269  X_batch.shape (100, 784)
# 270  X_batch.shape (100, 784)
# 271  X_batch.shape (100, 784)
# 272  X_batch.shape (100, 784)
# 273  X_batch.shape (100, 784)
# 274  X_batch.shape (100, 784)
# 275  X_batch.shape (100, 784)
# 276  X_batch.shape (100, 784)
# 277  X_batch.shape (100, 784)
# 278  X_batch.shape (100, 784)
# 279  X_batch.shape (100, 784)
# 280  X_batch.shape (100, 784)
# 281  X_batch.shape (100, 784)
# 282  X_batch.shape (100, 784)
# 283  X_batch.shape (100, 784)
# 284  X_batch.shape (100, 784)
# 285  X_batch.shape (100, 784)
# 286  X_batch.shape (100, 784)
# 287  X_batch.shape (100, 784)
# 288  X_batch.shape (100, 784)
# 289  X_batch.shape (100, 784)
# 290  X_batch.shape (100, 784)
# 291  X_batch.shape (100, 784)
# 292  X_batch.shape (100, 784)
# 293  X_batch.shape (100, 784)
# 294  X_batch.shape (100, 784)
# 295  X_batch.shape (100, 784)
# 296  X_batch.shape (100, 784)
# 297  X_batch.shape (100, 784)
# 298  X_batch.shape (100, 784)
# 299  X_batch.shape (100, 784)
# 300  X_batch.shape (100, 784)
# 301  X_batch.shape (100, 784)
# 302  X_batch.shape (100, 784)
# 303  X_batch.shape (100, 784)
# 304  X_batch.shape (100, 784)
# 305  X_batch.shape (100, 784)
# 306  X_batch.shape (100, 784)
# 307  X_batch.shape (100, 784)
# 308  X_batch.shape (100, 784)
# 309  X_batch.shape (100, 784)
# 310  X_batch.shape (100, 784)
# 311  X_batch.shape (100, 784)
# 312  X_batch.shape (100, 784)
# 313  X_batch.shape (100, 784)
# 314  X_batch.shape (100, 784)
# 315  X_batch.shape (100, 784)
# 316  X_batch.shape (100, 784)
# 317  X_batch.shape (100, 784)
# 318  X_batch.shape (100, 784)
# 319  X_batch.shape (100, 784)
# 320  X_batch.shape (100, 784)
# 321  X_batch.shape (100, 784)
# 322  X_batch.shape (100, 784)
# 323  X_batch.shape (100, 784)
# 324  X_batch.shape (100, 784)
# 325  X_batch.shape (100, 784)
# 326  X_batch.shape (100, 784)
# 327  X_batch.shape (100, 784)
# 328  X_batch.shape (100, 784)
# 329  X_batch.shape (100, 784)
# 330  X_batch.shape (100, 784)
# 331  X_batch.shape (100, 784)
# 332  X_batch.shape (100, 784)
# 333  X_batch.shape (100, 784)
# 334  X_batch.shape (100, 784)
# 335  X_batch.shape (100, 784)
# 336  X_batch.shape (100, 784)
# 337  X_batch.shape (100, 784)
# 338  X_batch.shape (100, 784)
# 339  X_batch.shape (100, 784)
# 340  X_batch.shape (100, 784)
# 341  X_batch.shape (100, 784)
# 342  X_batch.shape (100, 784)
# 343  X_batch.shape (100, 784)
# 344  X_batch.shape (100, 784)
# 345  X_batch.shape (100, 784)
# 346  X_batch.shape (100, 784)
# 347  X_batch.shape (100, 784)
# 348  X_batch.shape (100, 784)
# 349  X_batch.shape (100, 784)
# 350  X_batch.shape (100, 784)
# 351  X_batch.shape (100, 784)
# 352  X_batch.shape (100, 784)
# 353  X_batch.shape (100, 784)
# 354  X_batch.shape (100, 784)
# 355  X_batch.shape (100, 784)
# 356  X_batch.shape (100, 784)
# 357  X_batch.shape (100, 784)
# 358  X_batch.shape (100, 784)
# 359  X_batch.shape (100, 784)
# 360  X_batch.shape (100, 784)
# 361  X_batch.shape (100, 784)
# 362  X_batch.shape (100, 784)
# 363  X_batch.shape (100, 784)
# 364  X_batch.shape (100, 784)
# 365  X_batch.shape (100, 784)
# 366  X_batch.shape (100, 784)
# 367  X_batch.shape (100, 784)
# 368  X_batch.shape (100, 784)
# 369  X_batch.shape (100, 784)
# 370  X_batch.shape (100, 784)
# 371  X_batch.shape (100, 784)
# 372  X_batch.shape (100, 784)
# 373  X_batch.shape (100, 784)
# 374  X_batch.shape (100, 784)
# 375  X_batch.shape (100, 784)
# 376  X_batch.shape (100, 784)
# 377  X_batch.shape (100, 784)
# 378  X_batch.shape (100, 784)
# 379  X_batch.shape (100, 784)
# 380  X_batch.shape (100, 784)
# 381  X_batch.shape (100, 784)
# 382  X_batch.shape (100, 784)
# 383  X_batch.shape (100, 784)
# 384  X_batch.shape (100, 784)
# 385  X_batch.shape (100, 784)
# 386  X_batch.shape (100, 784)
# 387  X_batch.shape (100, 784)
# 388  X_batch.shape (100, 784)
# 389  X_batch.shape (100, 784)
# 390  X_batch.shape (100, 784)
# 391  X_batch.shape (100, 784)
# 392  X_batch.shape (100, 784)
# 393  X_batch.shape (100, 784)
# 394  X_batch.shape (100, 784)
# 395  X_batch.shape (100, 784)
# 396  X_batch.shape (100, 784)
# 397  X_batch.shape (100, 784)
# 398  X_batch.shape (100, 784)
# 399  X_batch.shape (100, 784)
# 400  X_batch.shape (100, 784)
# 401  X_batch.shape (100, 784)
# 402  X_batch.shape (100, 784)
# 403  X_batch.shape (100, 784)
# 404  X_batch.shape (100, 784)
# 405  X_batch.shape (100, 784)
# 406  X_batch.shape (100, 784)
# 407  X_batch.shape (100, 784)
# 408  X_batch.shape (100, 784)
# 409  X_batch.shape (100, 784)
# 410  X_batch.shape (100, 784)
# 411  X_batch.shape (100, 784)
# 412  X_batch.shape (100, 784)
# 413  X_batch.shape (100, 784)
# 414  X_batch.shape (100, 784)
# 415  X_batch.shape (100, 784)
# 416  X_batch.shape (100, 784)
# 417  X_batch.shape (100, 784)
# 418  X_batch.shape (100, 784)
# 419  X_batch.shape (100, 784)
# 420  X_batch.shape (100, 784)
# 421  X_batch.shape (100, 784)
# 422  X_batch.shape (100, 784)
# 423  X_batch.shape (100, 784)
# 424  X_batch.shape (100, 784)
# 425  X_batch.shape (100, 784)
# 426  X_batch.shape (100, 784)
# 427  X_batch.shape (100, 784)
# 428  X_batch.shape (100, 784)
# 429  X_batch.shape (100, 784)
# 430  X_batch.shape (100, 784)
# 431  X_batch.shape (100, 784)
# 432  X_batch.shape (100, 784)
# 433  X_batch.shape (100, 784)
# 434  X_batch.shape (100, 784)
# 435  X_batch.shape (100, 784)
# 436  X_batch.shape (100, 784)
# 437  X_batch.shape (100, 784)
# 438  X_batch.shape (100, 784)
# 439  X_batch.shape (100, 784)
# 440  X_batch.shape (100, 784)
# 441  X_batch.shape (100, 784)
# 442  X_batch.shape (100, 784)
# 443  X_batch.shape (100, 784)
# 444  X_batch.shape (100, 784)
# 445  X_batch.shape (100, 784)
# 446  X_batch.shape (100, 784)
# 447  X_batch.shape (100, 784)
# 448  X_batch.shape (100, 784)
# 449  X_batch.shape (100, 784)
# 450  X_batch.shape (100, 784)
# 451  X_batch.shape (100, 784)
# 452  X_batch.shape (100, 784)
# 453  X_batch.shape (100, 784)
# 454  X_batch.shape (100, 784)
# 455  X_batch.shape (100, 784)
# 456  X_batch.shape (100, 784)
# 457  X_batch.shape (100, 784)
# 458  X_batch.shape (100, 784)
# 459  X_batch.shape (100, 784)
# 460  X_batch.shape (100, 784)
# 461  X_batch.shape (100, 784)
# 462  X_batch.shape (100, 784)
# 463  X_batch.shape (100, 784)
# 464  X_batch.shape (100, 784)
# 465  X_batch.shape (100, 784)
# 466  X_batch.shape (100, 784)
# 467  X_batch.shape (100, 784)
# 468  X_batch.shape (100, 784)
# 469  X_batch.shape (100, 784)
# 470  X_batch.shape (100, 784)
# 471  X_batch.shape (100, 784)
# 472  X_batch.shape (100, 784)
# 473  X_batch.shape (100, 784)
# 474  X_batch.shape (100, 784)
# 475  X_batch.shape (100, 784)
# 476  X_batch.shape (100, 784)
# 477  X_batch.shape (100, 784)
# 478  X_batch.shape (100, 784)
# 479  X_batch.shape (100, 784)
# 480  X_batch.shape (100, 784)
# 481  X_batch.shape (100, 784)
# 482  X_batch.shape (100, 784)
# 483  X_batch.shape (100, 784)
# 484  X_batch.shape (100, 784)
# 485  X_batch.shape (100, 784)
# 486  X_batch.shape (100, 784)
# 487  X_batch.shape (100, 784)
# 488  X_batch.shape (100, 784)
# 489  X_batch.shape (100, 784)
# 490  X_batch.shape (100, 784)
# 491  X_batch.shape (100, 784)
# 492  X_batch.shape (100, 784)
# 493  X_batch.shape (100, 784)
# 494  X_batch.shape (100, 784)
# 495  X_batch.shape (100, 784)
# 496  X_batch.shape (100, 784)
# 497  X_batch.shape (100, 784)
# 498  X_batch.shape (100, 784)
# 499  X_batch.shape (100, 784)
# 500  X_batch.shape (100, 784)
# 501  X_batch.shape (100, 784)
# 502  X_batch.shape (100, 784)
# 503  X_batch.shape (100, 784)
# 504  X_batch.shape (100, 784)
# 505  X_batch.shape (100, 784)
# 506  X_batch.shape (100, 784)
# 507  X_batch.shape (100, 784)
# 508  X_batch.shape (100, 784)
# 509  X_batch.shape (100, 784)
# 510  X_batch.shape (100, 784)
# 511  X_batch.shape (100, 784)
# 512  X_batch.shape (100, 784)
# 513  X_batch.shape (100, 784)
# 514  X_batch.shape (100, 784)
# 515  X_batch.shape (100, 784)
# 516  X_batch.shape (100, 784)
# 517  X_batch.shape (100, 784)
# 518  X_batch.shape (100, 784)
# 519  X_batch.shape (100, 784)
# 520  X_batch.shape (100, 784)
# 521  X_batch.shape (100, 784)
# 522  X_batch.shape (100, 784)
# 523  X_batch.shape (100, 784)
# 524  X_batch.shape (100, 784)
# 525  X_batch.shape (100, 784)
# 526  X_batch.shape (100, 784)
# 527  X_batch.shape (100, 784)
# 528  X_batch.shape (100, 784)
# 529  X_batch.shape (100, 784)
# 530  X_batch.shape (100, 784)
# 531  X_batch.shape (100, 784)
# 532  X_batch.shape (100, 784)
# 533  X_batch.shape (100, 784)
# 534  X_batch.shape (100, 784)
# 535  X_batch.shape (100, 784)
# 536  X_batch.shape (100, 784)
# 537  X_batch.shape (100, 784)
# 538  X_batch.shape (100, 784)
# 539  X_batch.shape (100, 784)
# 540  X_batch.shape (100, 784)
# 541  X_batch.shape (100, 784)
# 542  X_batch.shape (100, 784)
# 543  X_batch.shape (100, 784)
# 544  X_batch.shape (100, 784)
# 545  X_batch.shape (100, 784)
# 546  X_batch.shape (100, 784)
# 547  X_batch.shape (100, 784)
# 548  X_batch.shape (100, 784)
# 549  X_batch.shape (100, 784)
# 550  X_batch.shape (100, 784)
# epoch  0
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# ResourceExhaustedError: OOM when allocating tensor with shape[10000,32,28,28] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: conv1/Conv2D = Conv2D[T=DT_FLOAT, data_format="NCHW", dilations=[1, 1, 1, 1], padding="SAME", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](conv1/Conv2D-0-TransposeNHWCToNCHW-LayoutOptimizer, conv1/kernel/read)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-6-516e7740737d> in <module>()
#      16         print('epoch ',epoch)
#      17         acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
# ---> 18         acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
#      19         print(epoch, "Last batch accuracy:", acc_batch, "Test accuracy:", acc_test)
#      20
#
# C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\framework\ops.py in eval(self, feed_dict, session)
#     705
#     706     """
# --> 707     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     708
#     709
#
# C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\framework\ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    5211                        "the tensor's graph is different from the session's "
#    5212                        "graph.")
# -> 5213   return session.run(tensors, feed_dict)
#    5214
#    5215
#
# C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333         except KeyError:
#    1334           pass
# -> 1335       raise type(e)(node_def, op, message)
#    1336
#    1337   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[10000,32,28,28] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: conv1/Conv2D = Conv2D[T=DT_FLOAT, data_format="NCHW", dilations=[1, 1, 1, 1], padding="SAME", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](conv1/Conv2D-0-TransposeNHWCToNCHW-LayoutOptimizer, conv1/kernel/read)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Caused by op 'conv1/Conv2D', defined at:
#   File "C:\Peter\Anaconda36\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Peter\Anaconda36\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Peter\Anaconda36\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Peter\Anaconda36\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Peter\Anaconda36\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Peter\Anaconda36\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Peter\Anaconda36\lib\asyncio\base_events.py", line 422, in run_forever
#     self._run_once()
#   File "C:\Peter\Anaconda36\lib\asyncio\base_events.py", line 1432, in _run_once
#     handle._run()
#   File "C:\Peter\Anaconda36\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Peter\Anaconda36\lib\site-packages\tornado\ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "C:\Peter\Anaconda36\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Peter\Anaconda36\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "C:\Peter\Anaconda36\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Peter\Anaconda36\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Peter\Anaconda36\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Peter\Anaconda36\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Peter\Anaconda36\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Peter\Anaconda36\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Peter\Anaconda36\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Peter\Anaconda36\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Peter\Anaconda36\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Peter\Anaconda36\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Peter\Anaconda36\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Peter\Anaconda36\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Peter\Anaconda36\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-675495a953e6>", line 30, in <module>
#     activation=tf.nn.relu, name="conv1")
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\layers\convolutional.py", line 427, in conv2d
#     return layer.apply(inputs)
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\keras\engine\base_layer.py", line 774, in apply
#     return self.__call__(inputs, *args, **kwargs)
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\layers\base.py", line 329, in __call__
#     outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\keras\engine\base_layer.py", line 703, in __call__
#     outputs = self.call(inputs, *args, **kwargs)
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\keras\layers\convolutional.py", line 184, in call
#     outputs = self._convolution_op(inputs, self.kernel)
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 868, in __call__
#     return self.conv_op(inp, filter)
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 520, in __call__
#     return self.call(inp, filter)
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 204, in __call__
#     name=self.name)
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py", line 1042, in conv2d
#     data_format=data_format, dilations=dilations, name=name)
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\framework\ops.py", line 3414, in create_op
#     op_def=op_def)
#   File "C:\Peter\Anaconda36\lib\site-packages\tensorflow\python\framework\ops.py", line 1740, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[10000,32,28,28] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: conv1/Conv2D = Conv2D[T=DT_FLOAT, data_format="NCHW", dilations=[1, 1, 1, 1], padding="SAME", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](conv1/Conv2D-0-TransposeNHWCToNCHW-LayoutOptimizer, conv1/kernel/read)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
