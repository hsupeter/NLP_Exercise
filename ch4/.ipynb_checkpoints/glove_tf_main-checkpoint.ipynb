# %%
from __future__ import division, print_function, unicode_literals
import tensorflow as tf
import numpy as np
from buil_dataset import word2VecDataset
from global_vector_model import gloVeModel
from tensorflow_graph_in_jupyter import show_graph

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# %%
if __name__ == '__main__':
    reset_graph()
    url = 'http://www.evanjones.ca/software/'
    w2v_dataset= word2VecDataset()    
    words = w2v_dataset.read_data('../wikipedia2text-extracted.txt.bz2', 18377035)
                
      
    text_digt,count,dictionary,reverse_dictionary =\
            w2v_dataset.build_dataset(words)
    
    del words
    print('text_digt:', [reverse_dictionary[di] for di in text_digt[:8]])
    
    #data_index = 0
    
    glv_mod = gloVeModel(num_steps = 100001)           
    #batch, labels, weights = glv_mod._generate_batch_GloVe(\
    #          text_digt, batch_size=8, window_size=4)
    #print('\nwith window_size = %d:' %window_size)
    #print('    batch:', [reverse_dictionary[bi] for bi in batch])
    #print('    labels:', [reverse_dictionary[li] for li\
    #                          in labels.reshape(8)])
    #print('    weights:', [w for w in weights])
        
   
    glv_mod.fit(text_digt = text_digt,\
                reverse_dictionary=reverse_dictionary,\
                batch_size =128, window_size=4)
# Out:
# Found and verified ../wikipedia2text-extracted.txt.bz2
# file_size 18377035
# Reading data...
# text_digt: ['propaganda', 'is', 'a', 'concerted', 'set', 'of', 'messages', 'aimed']
# (50000, 50000)
# Running 420093 iterations to compute the co-occurance matrix
# 	Finished 100000 iterations
# 	Finished 200000 iterations
# 	Finished 300000 iterations
# 	Finished 400000 iterations
# co-occurance type: <class 'scipy.sparse.lil.lil_matrix'>
# Initialized
#
# Average loss at step 0: 8.963708
# Nearest to "is": accurate, lived, 1933–1945, belittle, single-family, nada, necessary, ars,
# Nearest to ")": rmb, guinean, buoyed, zealots, offsetting, traducianism, bock, residencies,
# Nearest to "city": invertible, cylindrical, hourglass, wangari, ambition, kiwis, dfb, carleton,
# Nearest to "the": in, ., sociobiology, battled, dawa, fiscal, juanes, interval,
# Nearest to "'s": vineyard, pistol, intents, guitars, gesellschaft, godfrey, reconquer, plot,
# Nearest to "their": democrats, bends, tycoon, interpretive, adewale, difficulties, depths, lawman,
# Nearest to "not": residents, set, whorl, bayezid, volga-access, build, azoun, amauit,
# Nearest to "with": adjoined, 1958, jizhou, kilometre, |sep_rec_hi_°c, jakobson, despite, snowed,
# Nearest to "an": faunal, árpád, ammianus, zero, cavalry, vithalbhai, glitter, compositionally,
# Nearest to "a": solvay, shamir, rh, representation, diethyl, cordite, discernment, centauri,
# Nearest to "it": argentinean, |aug_hi_°c, aguinaldo, brooding, kipchaks, bueno, lenard, vast,
# Nearest to ":": kiev, differentiation, rutgers, diet, seventy-six, diracodon, nic, circled,
# Nearest to "``": water-rich, pregnant, multilinear, omnibenevolence, marksman, non-essential, emerges, sixth,
# Nearest to "first": shallows, coterie, pixels, doublet, agathias, 1906., differently, bottling,
# Nearest to "UNK": chi-lites, emissary, ne, i-18, pigs, jammu, 1652, package,
# Nearest to "are": vapor, mourning, precision—of, enshrined, banded, 'snapshot, unmodified, vocalic,
#
# Average loss at step 2000: 0.579840
# Nearest to "is": ., the, a, ,, was, and, in, that,
# Nearest to ")": (, UNK, ,, and, '', ., the, a,
# Nearest to "city": invertible, takeoffs, the, cylindrical, mainstream, hourglass, dowry, pamlico,
# Nearest to "the": of, ., in, and, ,, a, to, was,
# Nearest to "'s": of, ., the, and, in, ,, on, UNK,
# Nearest to "their": brunhilda, tycoon, democrats, to, adewale, difficulties, interpretive, bends,
# Nearest to "not": did, was, to, it, that, is, ,, be,
# Nearest to "with": ,, and, the, ., of, UNK, a, in,
# Nearest to "an": a, ,, such, aethelhere, as, ., powerplant, and,
# Nearest to "a": ,, and, the, ., of, was, as, in,
# Nearest to "it": was, is, be, to, not, ,, ., a,
# Nearest to ":": kiev, rutgers, differentiation, diet, nigel, nic, evinced, provision,
# Nearest to "``": '', UNK, ,, and, (, the, ., as,
# Nearest to "first": 1906., blooper, freemason, pixels, agathias, gayle, doublet, atholl,
# Nearest to "UNK": ,, and, (, ), ., the, in, of,
# Nearest to "are": there, ., and, ,, is, was, to, the,
#
# Average loss at step 4000: 0.098868
# Nearest to "is": ., the, to, a, was, in, and, ,,
# Nearest to ")": (, UNK, and, ,, '', ., in, the,
# Nearest to "city": invertible, takeoffs, cylindrical, of, pamlico, the, ., mainstream,
# Nearest to "the": of, ., in, and, ,, to, a, UNK,
# Nearest to "'s": of, ., and, in, the, on, ,, UNK,
# Nearest to "their": to, difficulties, is, brunhilda, democrats, legions, bends, tycoon,
# Nearest to "not": did, it, was, that, be, are, is, to,
# Nearest to "with": ,, and, of, the, ., a, in, to,
# Nearest to "an": ,, a, is, the, and, ., such, as,
# Nearest to "a": ,, and, the, of, in, as, ., to,
# Nearest to "it": was, is, a, to, ., ,, not, by,
# Nearest to ":": kiev, rutgers, evinced, diet, anticipation, nic, yaudheyas, shrugged,
# Nearest to "``": UNK, '', ,, and, as, the, a, (,
# Nearest to "first": blooper, 1906., freemason, gayle, pixels, atholl, agathias, secondary-school,
# Nearest to "UNK": and, ,, (, ), the, in, ., of,
# Nearest to "are": there, ., is, and, ,, was, in, the,
#
# Average loss at step 6000: 0.069931
# Nearest to "is": ., was, in, a, the, to, ,, that,
# Nearest to ")": (, UNK, ,, '', and, ., in, the,
# Nearest to "city": invertible, 's, of, the, ., takeoffs, cylindrical, pamlico,
# Nearest to "the": of, ., in, and, ,, to, a, UNK,
# Nearest to "'s": of, the, ., in, and, on, ,, UNK,
# Nearest to "their": to, difficulties, for, brunhilda, in, legions, and, tycoon,
# Nearest to "not": did, it, was, that, be, is, are, to,
# Nearest to "with": ,, and, the, of, a, ., in, UNK,
# Nearest to "an": a, is, ,, and, in, to, as, UNK,
# Nearest to "a": ,, and, the, ., of, in, as, to,
# Nearest to "it": was, is, not, that, to, a, ., ,,
# Nearest to ":": kiev, rutgers, ``, evinced, yaudheyas, diet, nic, reflections,
# Nearest to "``": '', UNK, ,, and, as, (, a, the,
# Nearest to "first": 1906., pixels, freemason, blooper, conformational, sinclair, manufactures, secondary-school,
# Nearest to "UNK": and, ,, ), (, the, ., in, a,
# Nearest to "are": ., ,, in, there, is, was, and, the,
#
# Average loss at step 8000: 0.068947
# Nearest to "is": ., was, a, in, the, ,, to, that,
# Nearest to ")": (, UNK, ,, '', and, ., in, the,
# Nearest to "city": 's, invertible, the, of, is, ., in, takeoffs,
# Nearest to "the": of, ., in, and, ,, a, to, for,
# Nearest to "'s": of, the, ., in, and, on, ,, UNK,
# Nearest to "their": to, for, difficulties, legions, and, was, ,, brunhilda,
# Nearest to "not": it, did, was, that, are, is, be, there,
# Nearest to "with": and, ,, a, the, of, in, ., UNK,
# Nearest to "an": a, is, ,, and, the, in, as, for,
# Nearest to "a": and, ,, the, of, ., in, as, is,
# Nearest to "it": is, was, not, that, are, ., ,, a,
# Nearest to ":": kiev, rutgers, ``, nic, evinced, eusebius, diet, UNK,
# Nearest to "``": '', UNK, ,, as, a, (, the, and,
# Nearest to "first": pixels, 1906., freemason, conformational, blooper, manufactures, sinclair, averlino,
# Nearest to "UNK": ,, and, (, ), the, in, ., a,
# Nearest to "are": is, ., and, ,, was, in, there, the,
#
# Average loss at step 10000: 0.058727
# Nearest to "is": ., was, the, a, in, to, that, for,
# Nearest to ")": (, UNK, ,, '', and, ., in, the,
# Nearest to "city": 's, of, the, invertible, ., is, in, takeoffs,
# Nearest to "the": ., of, in, and, ,, for, to, by,
# Nearest to "'s": the, ., of, in, and, ,, on, UNK,
# Nearest to "their": for, and, to, in, ,, were, legions, was,
# Nearest to "not": it, did, was, that, is, are, to, be,
# Nearest to "with": ,, and, a, the, of, ., in, UNK,
# Nearest to "an": ,, and, is, a, UNK, the, for, as,
# Nearest to "a": ,, and, ., the, of, in, is, UNK,
# Nearest to "it": is, was, that, not, are, to, a, .,
# Nearest to ":": kiev, rutgers, ``, UNK, evinced, nic, 1671, diet,
# Nearest to "``": '', UNK, ,, as, and, a, the, (,
# Nearest to "first": pixels, conformational, 1906., was, 's, the, freemason, in,
# Nearest to "UNK": and, ,, ), (, ., the, in, a,
# Nearest to "are": is, ., was, and, in, ,, the, there,
#
# Average loss at step 12000: 0.050740
# Nearest to "is": ., was, a, the, for, in, that, ,,
# Nearest to ")": (, UNK, '', ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., invertible, on, is, in,
# Nearest to "the": of, ., in, and, ,, for, a, to,
# Nearest to "'s": the, ., of, in, and, on, ,, by,
# Nearest to "their": to, for, in, ,, were, and, the, of,
# Nearest to "not": it, did, was, that, is, are, be, to,
# Nearest to "with": ,, and, a, the, of, in, for, UNK,
# Nearest to "an": a, is, ,, to, the, and, UNK, as,
# Nearest to "a": ,, and, the, ., of, is, to, for,
# Nearest to "it": is, was, that, not, a, to, ., by,
# Nearest to ":": ``, kiev, rutgers, UNK, 1671, evinced, (, nic,
# Nearest to "``": '', UNK, as, ,, a, and, (, the,
# Nearest to "first": pixels, 's, conformational, the, was, 1906., in, .,
# Nearest to "UNK": ,, and, ), (, the, ., in, a,
# Nearest to "are": and, ,, ., is, in, was, the, there,
#
# Average loss at step 14000: 0.060386
# Nearest to "is": ., was, the, a, for, in, that, ,,
# Nearest to ")": (, UNK, '', ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., on, invertible, is, in,
# Nearest to "the": ., of, in, and, ,, for, to, a,
# Nearest to "'s": ., the, of, in, on, and, ,, by,
# Nearest to "their": for, to, in, and, were, ,, from, the,
# Nearest to "not": it, did, was, that, is, are, be, to,
# Nearest to "with": ,, and, a, the, of, in, UNK, .,
# Nearest to "an": is, a, ,, and, for, as, UNK, the,
# Nearest to "a": ,, and, the, ., in, of, is, for,
# Nearest to "it": is, was, that, not, ., a, to, are,
# Nearest to ":": ``, rutgers, kiev, 1671, '', evinced, (, reflections,
# Nearest to "``": '', UNK, as, ,, and, a, (, .,
# Nearest to "first": 's, the, was, by, pixels, ., conformational, in,
# Nearest to "UNK": and, ,, ), (, the, ., in, a,
# Nearest to "are": ,, ., and, in, was, is, the, there,
# Average loss at step 16000: 0.047812
# Nearest to "is": was, ., a, for, to, the, that, in,
# Nearest to ")": (, UNK, '', ,, and, ., in, the,
# Nearest to "city": 's, the, of, ., on, invertible, in, is,
# Nearest to "the": of, ., in, and, ,, for, 's, to,
# Nearest to "'s": ., the, of, in, on, and, ,, by,
# Nearest to "their": for, from, and, in, to, ,, were, on,
# Nearest to "not": it, did, was, that, are, is, be, to,
# Nearest to "with": and, ,, a, the, of, in, for, UNK,
# Nearest to "an": a, is, and, ,, as, the, for, UNK,
# Nearest to "a": ,, and, the, of, ., for, in, UNK,
# Nearest to "it": is, was, that, not, to, ., a, are,
# Nearest to ":": ``, (, UNK, 1671, kiev, rutgers, reflections, '',
# Nearest to "``": '', UNK, as, ,, (, a, and, the,
# Nearest to "first": 's, the, world, in, ., by, of, was,
# Nearest to "UNK": ,, and, ), (, the, ., a, in,
# Nearest to "are": and, ., ,, in, is, was, the, by,
#
# Average loss at step 18000: 0.044738
# Nearest to "is": was, ., a, to, that, the, for, in,
# Nearest to ")": (, UNK, '', ,, and, in, ., the,
# Nearest to "city": 's, of, the, ., in, is, invertible, on,
# Nearest to "the": ., of, in, and, ,, for, a, to,
# Nearest to "'s": ., the, of, in, and, on, ,, from,
# Nearest to "their": from, for, in, and, were, ,, to, the,
# Nearest to "not": it, did, was, that, is, are, be, which,
# Nearest to "with": ,, and, a, the, of, in, UNK, .,
# Nearest to "an": a, is, ,, and, the, as, UNK, for,
# Nearest to "a": ,, and, the, of, is, ., with, for,
# Nearest to "it": is, was, not, that, ., to, also, a,
# Nearest to ":": ``, (, UNK, 1671, kiev, '', rutgers, resource-poor,
# Nearest to "``": '', UNK, as, ,, (, a, and, the,
# Nearest to "first": 's, the, world, in, of, ., was, at,
# Nearest to "UNK": and, ,, ), (, the, in, a, .,
# Nearest to "are": ., and, ,, in, is, was, the, were,
#
# Average loss at step 20000: 0.040375
# Nearest to "is": was, ., a, the, that, for, to, in,
# Nearest to ")": (, UNK, '', ,, and, in, ., or,
# Nearest to "city": 's, of, ., the, is, in, invertible, on,
# Nearest to "the": of, ., in, and, ,, for, 's, by,
# Nearest to "'s": the, ., of, in, on, and, ,, by,
# Nearest to "their": to, in, for, and, from, were, ,, the,
# Nearest to "not": it, was, did, that, is, be, are, which,
# Nearest to "with": and, ,, the, a, in, of, UNK, .,
# Nearest to "an": a, is, ,, and, for, as, the, UNK,
# Nearest to "a": and, ,, for, the, in, is, of, .,
# Nearest to "it": is, was, that, not, also, a, ., to,
# Nearest to ":": ``, (, UNK, 1671, ), '', rutgers, eusebius,
# Nearest to "``": '', UNK, as, ,, (, a, and, the,
# Nearest to "first": 's, the, in, world, of, ., was, at,
# Nearest to "UNK": ,, and, ), (, the, in, a, .,
# Nearest to "are": and, ., in, ,, the, was, by, is,
#
# Average loss at step 22000: 0.037857
# Nearest to "is": ., was, a, the, for, in, to, that,
# Nearest to ")": (, UNK, '', ,, and, or, ., in,
# Nearest to "city": of, 's, the, ., on, in, is, invertible,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, on, ,, UNK,
# Nearest to "their": to, for, and, from, in, ,, were, the,
# Nearest to "not": it, that, did, was, is, are, be, to,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, ,, for, and, in, the, as,
# Nearest to "a": ,, and, the, for, is, ., of, in,
# Nearest to "it": is, was, that, not, also, to, a, he,
# Nearest to ":": ``, (, UNK, 1671, '', kiev, eusebius, ),
# Nearest to "``": '', UNK, as, (, ,, a, and, the,
# Nearest to "first": 's, the, world, of, ., was, in, by,
# Nearest to "UNK": and, ,, (, ), the, ., in, a,
# Nearest to "are": and, ,, ., in, is, the, were, by,
#
# Average loss at step 24000: 0.038622
# Nearest to "is": was, ., a, for, in, to, the, that,
# Nearest to ")": (, UNK, '', ,, and, or, ., in,
# Nearest to "city": 's, of, the, ., in, on, is, invertible,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, on, and, ,, UNK,
# Nearest to "their": to, for, from, ,, and, in, were, the,
# Nearest to "not": it, did, was, that, are, is, be, which,
# Nearest to "with": ,, and, a, the, in, of, for, UNK,
# Nearest to "an": a, is, ,, and, for, UNK, as, in,
# Nearest to "a": ,, and, for, the, ., in, is, of,
# Nearest to "it": is, was, not, that, also, to, a, he,
# Nearest to ":": ``, (, UNK, '', 1671, ), eusebius, 's,
# Nearest to "``": '', UNK, a, as, (, ,, or, and,
# Nearest to "first": 's, the, ., world, of, in, was, by,
# Nearest to "UNK": and, ,, ), (, the, a, ., in,
# Nearest to "are": in, and, ., ,, were, by, is, was,
#
# Average loss at step 26000: 0.036734
# Nearest to "is": was, ., to, for, a, the, in, that,
# Nearest to ")": (, UNK, '', ,, and, or, ., in,
# Nearest to "city": of, 's, the, ., in, on, is, from,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": ., the, in, of, on, and, ,, for,
# Nearest to "their": for, from, to, in, and, ,, were, the,
# Nearest to "not": it, that, did, was, is, are, be, which,
# Nearest to "with": ,, and, a, the, of, in, for, .,
# Nearest to "an": a, is, ,, and, as, for, UNK, with,
# Nearest to "a": ,, and, for, the, with, ., as, in,
# Nearest to "it": is, was, that, not, also, this, to, a,
# Nearest to ":": ``, (, UNK, '', ), 1671, ., eusebius,
# Nearest to "``": '', UNK, as, ,, (, a, or, and,
# Nearest to "first": 's, the, in, ., world, of, to, was,
# Nearest to "UNK": ,, and, (, ), the, ., in, a,
# Nearest to "are": ., in, and, ,, were, the, is, by,
#
# Average loss at step 28000: 0.035945
# Nearest to "is": was, ., in, the, a, for, to, that,
# Nearest to ")": (, UNK, '', ,, and, or, ., in,
# Nearest to "city": 's, of, the, ., in, is, on, from,
# Nearest to "the": of, ., in, and, ,, for, 's, by,
# Nearest to "'s": the, ., of, in, and, on, ,, UNK,
# Nearest to "their": from, for, to, and, in, ,, were, the,
# Nearest to "not": it, was, did, that, are, be, is, to,
# Nearest to "with": and, ,, a, the, of, in, UNK, for,
# Nearest to "an": a, is, ,, as, and, for, in, UNK,
# Nearest to "a": ,, and, the, for, of, in, ., is,
# Nearest to "it": is, was, that, not, also, this, to, he,
# Nearest to ":": (, ``, UNK, '', 1671, ), the, eusebius,
# Nearest to "``": '', UNK, as, ,, a, or, (, and,
# Nearest to "first": 's, the, ., world, of, in, was, to,
# Nearest to "UNK": ,, and, (, ), the, in, ., a,
# Nearest to "are": and, ., in, ,, were, is, the, by,
#
# Average loss at step 30000: 0.034565
# Nearest to "is": ., was, a, the, for, in, to, that,
# Nearest to ")": (, UNK, '', ,, or, and, ., in,
# Nearest to "city": 's, of, the, ., in, on, is, from,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, on, ,, UNK,
# Nearest to "their": for, from, to, and, in, ,, the, on,
# Nearest to "not": it, was, that, did, are, be, is, to,
# Nearest to "with": ,, and, a, the, in, of, ., for,
# Nearest to "an": a, is, ,, and, UNK, for, as, the,
# Nearest to "a": ,, and, for, is, the, ., of, in,
# Nearest to "it": is, was, that, not, also, to, this, a,
# Nearest to ":": (, ``, UNK, '', ), 1671, 's, ,,
# Nearest to "``": '', UNK, as, ,, or, (, a, and,
# Nearest to "first": the, 's, world, ., in, of, at, was,
# Nearest to "UNK": ,, and, (, ), the, ., a, in,
# Nearest to "are": in, ., and, ,, were, is, the, by,
#
# Average loss at step 32000: 0.034451
# Nearest to "is": was, ., a, for, the, in, to, that,
# Nearest to ")": (, UNK, '', ,, or, and, ., in,
# Nearest to "city": 's, of, the, ., in, on, is, from,
# Nearest to "the": ., of, in, and, ,, for, 's, a,
# Nearest to "'s": the, ., of, in, and, ,, on, for,
# Nearest to "their": from, for, in, to, and, ,, of, the,
# Nearest to "not": it, was, that, did, are, is, be, to,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, ,, for, and, as, UNK, with,
# Nearest to "a": ,, and, for, the, is, with, of, .,
# Nearest to "it": is, was, that, not, also, this, a, to,
# Nearest to ":": (, ``, UNK, '', ), 's, 1671, and,
# Nearest to "``": '', UNK, as, or, ,, a, (, and,
# Nearest to "first": the, 's, ., world, of, in, was, to,
# Nearest to "UNK": ,, and, (, ), ., a, the, in,
# Nearest to "are": were, and, in, ., ,, is, by, the,
#
# Average loss at step 34000: 0.032977
# Nearest to "is": was, ., a, for, the, in, to, that,
# Nearest to ")": (, UNK, '', or, and, ,, ., in,
# Nearest to "city": 's, of, the, ., in, on, is, from,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, of, ., in, and, ,, on, UNK,
# Nearest to "their": from, for, ,, to, and, in, the, of,
# Nearest to "not": it, was, that, did, is, are, be, were,
# Nearest to "with": ,, and, a, the, of, in, UNK, for,
# Nearest to "an": a, is, ,, for, as, and, the, with,
# Nearest to "a": ,, and, for, the, with, is, of, .,
# Nearest to "it": is, was, not, that, also, this, a, he,
# Nearest to ":": ``, (, UNK, '', ), and, 's, .,
# Nearest to "``": '', UNK, as, or, a, ,, and, (,
# Nearest to "first": 's, the, ., of, world, in, was, at,
# Nearest to "UNK": and, ,, ), (, the, ., in, a,
# Nearest to "are": were, ., and, in, is, ,, was, by,
# Average loss at step 36000: 0.030945
# Nearest to "is": was, ., a, for, in, the, to, that,
# Nearest to ")": (, UNK, '', or, ,, and, ., in,
# Nearest to "city": 's, of, the, ., in, on, is, from,
# Nearest to "the": ., of, in, and, ,, for, 's, a,
# Nearest to "'s": the, ., of, in, and, ,, on, UNK,
# Nearest to "their": from, for, to, and, in, ,, the, of,
# Nearest to "not": it, was, that, did, is, are, be, were,
# Nearest to "with": ,, and, a, the, of, in, for, UNK,
# Nearest to "an": a, is, ,, as, for, and, the, UNK,
# Nearest to "a": ,, and, the, ., for, of, with, is,
# Nearest to "it": is, was, also, not, that, this, he, a,
# Nearest to ":": (, ``, UNK, '', ), from, 's, and,
# Nearest to "``": '', UNK, as, or, a, ,, and, (,
# Nearest to "first": 's, the, ., of, in, world, to, was,
# Nearest to "UNK": and, ,, ), (, the, a, ., in,
# Nearest to "are": were, ., in, ,, and, is, by, the,
#
# Average loss at step 38000: 0.030494
# Nearest to "is": was, ., a, for, to, the, in, that,
# Nearest to ")": (, UNK, '', or, ,, and, ., in,
# Nearest to "city": 's, of, the, ., on, in, from, is,
# Nearest to "the": ., of, in, and, ,, for, 's, a,
# Nearest to "'s": the, ., of, in, and, ,, on, by,
# Nearest to "their": for, from, to, and, ,, in, the, of,
# Nearest to "not": it, was, that, did, is, are, be, were,
# Nearest to "with": and, ,, a, the, in, of, for, .,
# Nearest to "an": a, is, ,, for, and, as, UNK, to,
# Nearest to "a": ,, and, the, for, is, ., of, in,
# Nearest to "it": is, was, that, also, not, this, he, a,
# Nearest to ":": (, ``, UNK, '', ), the, eusebius, from,
# Nearest to "``": '', UNK, or, as, a, ,, (, and,
# Nearest to "first": 's, the, ., of, in, world, at, was,
# Nearest to "UNK": and, ,, (, ), or, ., the, a,
# Nearest to "are": were, and, ., ,, in, is, the, by,
#
# Average loss at step 40000: 0.030525
# Nearest to "is": was, ., a, for, the, to, in, that,
# Nearest to ")": (, UNK, '', or, ,, and, ., in,
# Nearest to "city": 's, of, the, ., on, in, from, is,
# Nearest to "the": of, ., in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, ,, on, at,
# Nearest to "their": from, for, to, and, in, the, ,, of,
# Nearest to "not": it, was, that, did, is, be, were, are,
# Nearest to "with": ,, and, a, the, in, of, for, UNK,
# Nearest to "an": a, is, for, ,, to, as, and, the,
# Nearest to "a": ,, and, for, is, the, ., of, in,
# Nearest to "it": is, was, that, also, not, this, he, a,
# Nearest to ":": (, ``, UNK, '', ), eusebius, or, the,
# Nearest to "``": '', UNK, or, as, ,, a, (, and,
# Nearest to "first": 's, the, ., of, in, world, by, at,
# Nearest to "UNK": and, ,, ), (, or, the, ., in,
# Nearest to "are": were, ,, and, ., in, is, the, by,
#
# Average loss at step 42000: 0.029512
# Nearest to "is": a, was, ., the, to, in, for, that,
# Nearest to ")": (, UNK, '', or, and, ,, ., in,
# Nearest to "city": 's, of, the, ., in, on, is, from,
# Nearest to "the": ., of, in, and, ,, for, 's, a,
# Nearest to "'s": the, ., of, in, and, ,, on, by,
# Nearest to "their": from, for, and, to, in, ,, the, his,
# Nearest to "not": it, that, was, did, is, be, are, also,
# Nearest to "with": ,, and, a, the, in, of, for, UNK,
# Nearest to "an": a, is, ,, for, as, UNK, and, with,
# Nearest to "a": ,, and, the, for, is, ., of, with,
# Nearest to "it": is, was, that, also, not, this, he, a,
# Nearest to ":": (, ``, UNK, '', ), or, and, the,
# Nearest to "``": '', UNK, or, as, a, ,, and, (,
# Nearest to "first": 's, the, ., in, of, world, by, to,
# Nearest to "UNK": and, ,, (, ), or, a, ., the,
# Nearest to "are": were, ., and, in, ,, is, the, by,
#
# Average loss at step 44000: 0.028036
# Nearest to "is": ., was, a, the, in, for, to, that,
# Nearest to ")": (, UNK, '', or, ,, and, ., in,
# Nearest to "city": 's, of, the, ., in, on, is, most,
# Nearest to "the": ., of, in, and, ,, for, to, 's,
# Nearest to "'s": the, of, ., in, and, ,, on, UNK,
# Nearest to "their": from, for, and, to, in, the, ,, its,
# Nearest to "not": it, was, that, did, is, be, were, also,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, for, is, ,, and, with, UNK, to,
# Nearest to "a": ,, and, for, the, is, ., in, with,
# Nearest to "it": is, was, also, that, not, this, he, a,
# Nearest to ":": (, ``, UNK, '', ), or, ,, and,
# Nearest to "``": '', UNK, or, as, a, ,, and, (,
# Nearest to "first": the, 's, ., of, in, world, at, was,
# Nearest to "UNK": and, ,, ), (, or, the, ., in,
# Nearest to "are": were, in, ., and, ,, the, is, by,
#
# Average loss at step 46000: 0.028841
# Nearest to "is": ., a, was, the, for, in, to, that,
# Nearest to ")": (, UNK, '', or, ,, and, ., in,
# Nearest to "city": 's, of, the, ., in, on, is, from,
# Nearest to "the": ., of, in, and, ,, for, by, to,
# Nearest to "'s": the, ., of, in, and, ,, on, by,
# Nearest to "their": from, to, for, in, and, its, his, on,
# Nearest to "not": it, was, that, did, is, are, be, also,
# Nearest to "with": ,, and, a, the, in, of, ., for,
# Nearest to "an": a, is, ,, for, to, with, and, the,
# Nearest to "a": ,, is, and, for, the, ., in, with,
# Nearest to "it": is, was, also, that, not, this, he, a,
# Nearest to ":": (, ``, UNK, '', ), or, and, ,,
# Nearest to "``": '', UNK, or, as, ,, a, (, and,
# Nearest to "first": the, 's, ., of, in, world, at, was,
# Nearest to "UNK": ,, and, ), (, or, ., the, a,
# Nearest to "are": were, in, ., ,, and, by, is, the,
#
# Average loss at step 48000: 0.027873
# Nearest to "is": ., a, was, in, for, the, to, that,
# Nearest to ")": (, UNK, '', or, ,, and, ., in,
# Nearest to "city": 's, of, the, ., in, on, is, from,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, ,, on, UNK,
# Nearest to "their": to, for, from, and, in, its, ,, the,
# Nearest to "not": it, was, that, did, is, are, which, be,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, ,, for, and, UNK, with, as,
# Nearest to "a": ,, and, for, is, the, ., of, in,
# Nearest to "it": is, was, that, also, not, this, he, a,
# Nearest to ":": ``, (, UNK, '', or, ), and, ,,
# Nearest to "``": '', UNK, or, as, ,, a, (, and,
# Nearest to "first": the, 's, ., of, world, in, at, was,
# Nearest to "UNK": and, ,, ), (, or, ., the, in,
# Nearest to "are": were, and, in, ,, ., by, is, the,
#
# Average loss at step 50000: 0.121147
# Nearest to "is": ., was, a, in, to, the, that, for,
# Nearest to ")": (, '', or, ,, and, ., in, ;,
# Nearest to "city": 's, the, of, ., in, on, is, from,
# Nearest to "the": ., in, of, and, ,, for, a, 's,
# Nearest to "'s": the, ., in, of, and, ,, on, at,
# Nearest to "their": for, to, from, its, and, ,, in, his,
# Nearest to "not": it, was, did, that, is, are, be, also,
# Nearest to "with": ,, and, a, the, in, for, ., to,
# Nearest to "an": a, is, ,, as, with, and, the, to,
# Nearest to "a": ,, and, the, is, ., for, in, with,
# Nearest to "it": is, was, that, also, this, not, he, a,
# Nearest to ":": ``, (, '', ), or, 's, and, ,,
# Nearest to "``": '', or, as, ,, (, a, and, the,
# Nearest to "first": 's, the, ., in, of, world, at, was,
# Nearest to "UNK": =, for, ,, ., and, in, from, the,
# Nearest to "are": were, in, ., ,, and, by, is, the,
#
# Average loss at step 52000: 0.907724
# Nearest to "is": ., was, a, for, to, the, that, in,
# Nearest to ")": (, '', or, ,, and, in, ., the,
# Nearest to "city": 's, of, the, ., in, on, is, to,
# Nearest to "the": of, ., in, and, ,, for, 's, to,
# Nearest to "'s": ., the, of, in, and, on, ,, at,
# Nearest to "their": from, to, for, its, and, in, ,, the,
# Nearest to "not": it, was, did, that, is, also, which, were,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, ,, as, for, with, and, to,
# Nearest to "a": ,, and, for, the, is, ., of, with,
# Nearest to "it": is, was, also, that, not, this, he, a,
# Nearest to ":": ``, (, '', or, ), 's, and, .,
# Nearest to "``": '', or, as, ,, a, and, (, .,
# Nearest to "first": 's, the, ., of, world, in, at, by,
# Nearest to "UNK": ;, (, agent, and, ,, relegated, distance, javan,
# Nearest to "are": were, and, in, ., ,, by, was, is,
#
# Average loss at step 54000: 0.051612
# Nearest to "is": was, a, ., to, the, for, in, that,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., on, in, is, to,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, ,, on, at,
# Nearest to "their": to, and, from, its, for, ,, in, were,
# Nearest to "not": it, was, did, that, also, is, were, be,
# Nearest to "with": and, ,, a, the, of, in, for, .,
# Nearest to "an": a, is, as, ,, for, and, to, with,
# Nearest to "a": ,, and, is, for, the, ., of, with,
# Nearest to "it": is, was, also, that, not, this, he, to,
# Nearest to ":": ``, (, '', ), or, and, the, .,
# Nearest to "``": '', or, as, (, ,, a, and, 's,
# Nearest to "first": 's, the, ., of, in, world, at, by,
# Nearest to "UNK": (, agent, javan, distance, relegated, tā, melted, and,
# Nearest to "are": were, in, ., and, ,, by, the, was,
# Average loss at step 56000: 0.037679
# Nearest to "is": a, ., was, for, the, in, to, by,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., on, in, is, from,
# Nearest to "the": of, ., in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, on, and, ,, at,
# Nearest to "their": to, its, and, for, from, in, ,, his,
# Nearest to "not": it, did, was, that, also, is, were, be,
# Nearest to "with": and, ,, a, the, of, in, for, .,
# Nearest to "an": a, is, for, as, ,, to, the, and,
# Nearest to "a": ,, and, is, for, the, of, ., with,
# Nearest to "it": is, was, also, that, not, this, he, a,
# Nearest to ":": ``, (, '', ), or, and, ., ,,
# Nearest to "``": '', or, as, ,, (, a, and, the,
# Nearest to "first": 's, the, ., at, of, in, by, world,
# Nearest to "UNK": (, melted, javan, relegated, distance, and, ), ,,
# Nearest to "are": were, in, ., and, ,, by, is, the,
#
# Average loss at step 58000: 0.031830
# Nearest to "is": a, was, ., for, to, the, in, it,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., on, in, most, from,
# Nearest to "the": of, ., in, and, ,, for, 's, to,
# Nearest to "'s": ., the, of, in, on, and, ,, at,
# Nearest to "their": to, for, its, and, in, from, his, the,
# Nearest to "not": it, was, did, that, is, also, be, were,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, ,, as, to, for, and, the,
# Nearest to "a": ,, and, for, the, ., is, in, of,
# Nearest to "it": is, was, also, that, not, this, he, a,
# Nearest to ":": ``, (, '', ), or, of, ., 's,
# Nearest to "``": '', or, as, ,, (, a, and, .,
# Nearest to "first": 's, the, of, ., at, in, by, world,
# Nearest to "UNK": (, ), and, melted, javan, relegated, distance, tā,
# Nearest to "are": were, in, ., and, ,, by, the, is,
#
# Average loss at step 60000: 0.029254
# Nearest to "is": was, ., a, to, for, in, the, by,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., in, on, from, most,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, on, ,, at,
# Nearest to "their": to, its, for, and, from, in, his, ,,
# Nearest to "not": it, was, did, that, were, is, be, also,
# Nearest to "with": and, ,, a, the, in, of, for, .,
# Nearest to "an": a, is, as, ,, to, for, and, the,
# Nearest to "a": ,, and, for, the, is, ., of, in,
# Nearest to "it": is, was, also, not, that, this, he, a,
# Nearest to ":": ``, (, '', ), or, ., the, and,
# Nearest to "``": '', or, as, a, ,, (, and, the,
# Nearest to "first": 's, the, of, ., at, in, world, by,
# Nearest to "UNK": (, ), and, melted, javan, relegated, ,, with,
# Nearest to "are": were, and, ., in, ,, by, the, is,
#
# Average loss at step 62000: 0.028096
# Nearest to "is": ., a, was, to, for, the, in, ,,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, ., the, in, on, from, is,
# Nearest to "the": of, ., in, and, ,, for, 's, to,
# Nearest to "'s": ., the, of, in, and, on, ,, at,
# Nearest to "their": its, to, and, for, from, in, ,, his,
# Nearest to "not": it, was, that, did, also, is, which, be,
# Nearest to "with": ,, and, a, the, of, in, for, .,
# Nearest to "an": a, is, as, ,, to, for, with, the,
# Nearest to "a": ,, and, for, the, is, in, with, .,
# Nearest to "it": was, is, also, not, that, this, he, to,
# Nearest to ":": ``, (, '', ), the, or, ., 's,
# Nearest to "``": '', or, as, a, ,, (, and, the,
# Nearest to "first": 's, the, ., of, at, in, world, by,
# Nearest to "UNK": (, ), ,, with, and, melted, or, relegated,
# Nearest to "are": were, ., in, and, ,, by, the, is,
#
# Average loss at step 64000: 0.027818
# Nearest to "is": ., a, to, was, for, the, in, of,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., in, on, is, from,
# Nearest to "the": of, ., in, and, ,, 's, for, to,
# Nearest to "'s": the, ., of, in, and, on, ,, from,
# Nearest to "their": its, for, to, from, and, his, in, the,
# Nearest to "not": it, was, did, that, were, also, be, is,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, as, ,, for, to, with, in,
# Nearest to "a": ,, and, the, for, is, of, ., in,
# Nearest to "it": is, was, also, that, this, not, he, to,
# Nearest to ":": ``, (, '', ), or, ., 's, the,
# Nearest to "``": '', as, or, a, ,, (, and, the,
# Nearest to "first": 's, the, ., in, of, at, world, by,
# Nearest to "UNK": (, ), with, ,, and, or, by, melted,
# Nearest to "are": were, in, and, ., ,, by, is, the,
#
# Average loss at step 66000: 0.027159
# Nearest to "is": ., a, was, the, for, to, in, of,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., in, on, is, most,
# Nearest to "the": of, ., in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, on, ,, at,
# Nearest to "their": its, to, for, from, and, in, his, ,,
# Nearest to "not": it, that, did, was, also, were, be, is,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, ,, as, for, to, in, the,
# Nearest to "a": ,, and, is, for, the, ., of, in,
# Nearest to "it": is, was, also, not, that, this, he, a,
# Nearest to ":": ``, (, '', ), 's, the, or, of,
# Nearest to "``": '', as, or, a, ,, (, and, the,
# Nearest to "first": 's, the, of, ., at, world, in, by,
# Nearest to "UNK": (, ), ,, with, and, or, by, melted,
# Nearest to "are": were, in, and, ., ,, the, by, is,
#
# Average loss at step 68000: 0.026380
# Nearest to "is": ., a, was, for, to, the, in, ,,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., on, in, from, is,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": ., the, of, in, and, on, ,, at,
# Nearest to "their": its, from, for, and, to, in, his, the,
# Nearest to "not": it, that, was, did, also, is, they, be,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, ,, as, for, with, and, in,
# Nearest to "a": ,, and, is, ., the, for, of, in,
# Nearest to "it": is, was, also, this, that, not, he, a,
# Nearest to ":": ``, (, '', ), or, 's, the, .,
# Nearest to "``": '', or, as, ,, a, and, (, .,
# Nearest to "first": 's, the, ., at, of, world, in, by,
# Nearest to "UNK": (, ), and, with, ,, or, by, a,
# Nearest to "are": were, in, and, ., ,, the, is, by,
#
# Average loss at step 70000: 0.026312
# Nearest to "is": ., was, a, for, the, to, in, of,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., on, in, from, is,
# Nearest to "the": of, ., in, and, ,, for, 's, by,
# Nearest to "'s": the, ., of, in, on, and, ,, by,
# Nearest to "their": its, for, to, in, from, his, and, the,
# Nearest to "not": it, that, did, was, also, be, they, were,
# Nearest to "with": ,, and, a, the, in, for, of, .,
# Nearest to "an": a, is, ,, for, as, with, to, the,
# Nearest to "a": ,, and, is, for, the, in, ., of,
# Nearest to "it": is, was, also, this, that, not, he, to,
# Nearest to ":": ``, (, '', ), or, 's, the, .,
# Nearest to "``": '', or, as, ,, (, a, and, the,
# Nearest to "first": 's, the, ., of, at, world, in, by,
# Nearest to "UNK": (, ), and, with, ,, or, a, by,
# Nearest to "are": were, in, ., and, ,, the, by, is,
#
# Average loss at step 72000: 0.025375
# Nearest to "is": ., a, was, for, the, in, to, by,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., in, on, from, at,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": ., the, of, in, and, on, ,, at,
# Nearest to "their": its, for, to, from, in, his, and, the,
# Nearest to "not": it, did, was, that, be, can, also, is,
# Nearest to "with": ,, and, a, the, in, for, of, .,
# Nearest to "an": a, is, ,, with, for, in, to, as,
# Nearest to "a": ,, and, for, is, the, ., in, with,
# Nearest to "it": is, was, also, that, this, not, he, by,
# Nearest to ":": ``, (, '', ), 's, or, of, .,
# Nearest to "``": '', or, as, ,, a, and, (, .,
# Nearest to "first": 's, the, at, ., of, world, by, in,
# Nearest to "UNK": (, ), and, with, ,, or, by, a,
# Nearest to "are": were, ., and, in, ,, the, by, is,
#
# Average loss at step 74000: 0.024411
# Nearest to "is": was, ., a, for, in, the, that, to,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., in, on, from, at,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, on, ,, at,
# Nearest to "their": its, to, from, and, for, in, his, the,
# Nearest to "not": it, was, that, did, be, can, also, is,
# Nearest to "with": ,, and, a, the, in, for, of, .,
# Nearest to "an": is, a, for, ,, with, as, to, in,
# Nearest to "a": ,, and, for, the, is, of, ., with,
# Nearest to "it": is, was, also, that, not, this, he, to,
# Nearest to ":": ``, (, '', ), or, the, ., 's,
# Nearest to "``": '', or, as, ,, a, and, (, the,
# Nearest to "first": 's, the, at, ., of, in, world, was,
# Nearest to "UNK": (, ), with, and, ,, or, by, from,
# Nearest to "are": were, in, ., and, ,, by, is, the,
# Average loss at step 76000: 0.024013
# Nearest to "is": a, ., was, the, in, for, to, it,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, ., the, in, on, from, at,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, ,, on, at,
# Nearest to "their": its, to, from, and, for, his, in, ,,
# Nearest to "not": it, that, was, did, they, is, also, be,
# Nearest to "with": ,, and, a, the, in, for, of, .,
# Nearest to "an": is, a, for, as, with, ,, in, to,
# Nearest to "a": ,, and, for, the, is, with, in, .,
# Nearest to "it": is, was, also, that, not, this, he, a,
# Nearest to ":": ``, (, '', ), or, 's, ., of,
# Nearest to "``": '', or, as, ,, a, (, and, the,
# Nearest to "first": 's, the, at, ., of, world, in, by,
# Nearest to "UNK": (, ), with, and, ,, or, from, by,
# Nearest to "are": were, in, ., and, ,, by, the, is,
#
# Average loss at step 78000: 0.024538
# Nearest to "is": ., a, was, to, the, for, in, it,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., in, on, from, is,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, on, ,, at,
# Nearest to "their": its, for, to, from, and, in, his, ,,
# Nearest to "not": it, that, was, did, also, they, can, is,
# Nearest to "with": and, ,, a, the, in, of, for, .,
# Nearest to "an": a, is, for, as, ,, with, to, in,
# Nearest to "a": and, ,, for, the, is, ., with, of,
# Nearest to "it": is, was, also, that, not, this, he, to,
# Nearest to ":": ``, (, '', ), ., or, of, 's,
# Nearest to "``": '', or, as, ,, (, a, and, .,
# Nearest to "first": 's, the, at, ., of, in, world, by,
# Nearest to "UNK": (, ), and, with, ,, or, a, by,
# Nearest to "are": were, in, ., and, ,, the, by, is,
#
# Average loss at step 80000: 0.074705
# Nearest to "is": a, ., was, the, to, in, for, it,
# Nearest to ")": (, or, and, ,, ., in, '', the,
# Nearest to "city": 's, of, the, ., on, in, from, most,
# Nearest to "the": of, ., in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, on, ,, at,
# Nearest to "their": its, from, to, for, and, his, in, the,
# Nearest to "not": it, that, was, did, also, they, can, is,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, as, for, ,, with, to, and,
# Nearest to "a": ,, and, for, is, the, in, with, .,
# Nearest to "it": is, was, also, that, not, this, he, to,
# Nearest to ":": ``, (, ), '', ., of, or, the,
# Nearest to "``": '', or, as, ,, (, a, and, .,
# Nearest to "first": 's, the, at, ., of, in, world, was,
# Nearest to "UNK": (, ), ,, and, with, '', by, a,
# Nearest to "are": were, and, ., in, ,, the, by, is,
#
# Average loss at step 82000: 0.023395
# Nearest to "is": a, ., was, to, in, the, for, it,
# Nearest to ")": (, or, ,, and, '', in, ., the,
# Nearest to "city": 's, of, the, ., on, in, from, is,
# Nearest to "the": ., of, in, and, ,, for, 's, by,
# Nearest to "'s": the, ., of, in, and, on, ,, by,
# Nearest to "their": its, from, to, and, his, for, in, ,,
# Nearest to "not": it, that, was, did, also, can, they, is,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, as, for, ,, to, with, in,
# Nearest to "a": ,, and, is, for, the, ., in, with,
# Nearest to "it": is, was, also, that, not, this, he, to,
# Nearest to ":": ``, (, '', ), of, the, ., or,
# Nearest to "``": '', or, as, (, ,, a, and, the,
# Nearest to "first": 's, the, ., at, of, in, world, by,
# Nearest to "UNK": (, ), '', and, ,, with, by, a,
# Nearest to "are": were, ., and, in, ,, the, by, is,
#
# Average loss at step 84000: 0.023119
# Nearest to "is": a, ., for, was, to, that, in, the,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, ., the, on, in, from, by,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, on, ,, by,
# Nearest to "their": its, from, and, his, to, for, in, the,
# Nearest to "not": it, that, also, can, did, was, they, is,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, for, ,, to, as, with, in,
# Nearest to "a": ,, for, and, the, is, with, ., in,
# Nearest to "it": is, was, also, that, not, this, he, a,
# Nearest to ":": ``, (, '', ), the, or, ., of,
# Nearest to "``": '', or, as, (, ,, a, and, .,
# Nearest to "first": 's, the, ., at, of, world, in, by,
# Nearest to "UNK": (, ), '', and, ,, with, by, or,
# Nearest to "are": were, in, ., and, ,, the, by, for,
#
# Average loss at step 86000: 0.021943
# Nearest to "is": a, ., was, to, for, the, that, in,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, ., the, in, on, from, most,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, on, ,, by,
# Nearest to "their": its, from, and, to, for, his, in, were,
# Nearest to "not": it, that, was, also, did, can, they, is,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": a, is, for, with, as, ,, to, the,
# Nearest to "a": ,, and, is, with, for, the, ., of,
# Nearest to "it": is, was, also, that, not, this, he, to,
# Nearest to ":": ``, (, '', ), ., of, the, or,
# Nearest to "``": '', or, as, ,, a, and, (, ),
# Nearest to "first": 's, the, of, ., in, at, world, by,
# Nearest to "UNK": (, ), '', and, with, ,, by, or,
# Nearest to "are": were, and, in, ., ,, the, by, is,
#
# Average loss at step 88000: 0.021657
# Nearest to "is": a, ., was, in, to, for, the, it,
# Nearest to ")": (, '', or, ,, and, in, ., the,
# Nearest to "city": 's, of, the, ., in, on, from, most,
# Nearest to "the": ., of, in, and, ,, for, 's, to,
# Nearest to "'s": the, ., of, in, and, on, ,, from,
# Nearest to "their": its, from, and, to, his, for, were, in,
# Nearest to "not": it, that, was, also, did, can, they, is,
# Nearest to "with": ,, and, a, the, in, for, of, .,
# Nearest to "an": a, is, for, as, ,, with, to, and,
# Nearest to "a": ,, and, for, is, the, with, ., in,
# Nearest to "it": is, was, also, that, not, this, he, to,
# Nearest to ":": ``, (, '', ), 's, or, ., of,
# Nearest to "``": '', or, as, ,, a, (, and, the,
# Nearest to "first": 's, the, ., of, at, in, world, by,
# Nearest to "UNK": (, ), '', and, with, ,, or, by,
# Nearest to "are": were, ., and, in, ,, the, by, is,
#
# Average loss at step 90000: 0.021593
# Nearest to "is": a, ., was, for, the, in, to, that,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., in, on, from, most,
# Nearest to "the": ., of, in, and, ,, for, to, 's,
# Nearest to "'s": the, ., of, in, and, on, ,, from,
# Nearest to "their": its, from, to, and, for, his, in, were,
# Nearest to "not": it, was, that, can, also, did, they, be,
# Nearest to "with": ,, and, a, the, in, of, for, .,
# Nearest to "an": is, a, for, as, ,, with, to, the,
# Nearest to "a": ,, and, for, is, the, ., with, of,
# Nearest to "it": is, was, also, that, this, not, he, a,
# Nearest to ":": ``, (, '', ), 's, ., or, the,
# Nearest to "``": '', or, as, ,, a, (, and, .,
# Nearest to "first": 's, the, ., of, at, in, world, to,
# Nearest to "UNK": (, ), '', and, with, ,, or, from,
# Nearest to "are": were, ., in, and, ,, the, is, by,
#
# Average loss at step 92000: 0.022482
# Nearest to "is": a, ., was, the, in, to, for, that,
# Nearest to ")": (, '', or, ,, and, in, ., the,
# Nearest to "city": 's, of, the, ., in, on, from, most,
# Nearest to "the": of, ., in, and, ,, for, 's, by,
# Nearest to "'s": the, ., of, in, and, on, ,, at,
# Nearest to "their": its, for, to, from, and, his, in, were,
# Nearest to "not": it, that, was, can, also, did, be, is,
# Nearest to "with": ,, and, a, the, in, of, ., for,
# Nearest to "an": a, is, as, for, ,, with, to, the,
# Nearest to "a": ,, is, and, the, with, for, in, .,
# Nearest to "it": is, was, also, that, this, not, he, to,
# Nearest to ":": ``, (, '', ), or, the, ., 's,
# Nearest to "``": '', or, as, ,, (, a, and, the,
# Nearest to "first": 's, the, at, ., of, in, world, by,
# Nearest to "UNK": (, ), '', ,, and, with, or, from,
# Nearest to "are": were, ., in, and, ,, the, is, by,
#
# Average loss at step 94000: 0.021223
# Nearest to "is": a, ., was, in, the, for, to, that,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., in, on, from, most,
# Nearest to "the": ., of, in, and, ,, for, 's, by,
# Nearest to "'s": the, ., of, in, and, on, ,, at,
# Nearest to "their": its, to, for, and, from, his, in, were,
# Nearest to "not": it, that, was, can, did, also, is, be,
# Nearest to "with": ,, and, a, the, in, of, ., for,
# Nearest to "an": a, is, as, for, ,, with, to, in,
# Nearest to "a": ,, and, is, the, for, ., of, in,
# Nearest to "it": is, was, also, that, not, this, he, a,
# Nearest to ":": ``, (, '', ), ., or, of, 's,
# Nearest to "``": '', or, as, ,, (, a, and, .,
# Nearest to "first": 's, the, ., at, of, in, world, by,
# Nearest to "UNK": (, ), '', and, ,, with, or, a,
# Nearest to "are": were, in, ., and, ,, the, is, for,
# Average loss at step 96000: 0.021005
# Nearest to "is": a, ., was, in, the, for, to, that,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., on, in, from, is,
# Nearest to "the": ., of, in, and, ,, for, 's, by,
# Nearest to "'s": the, of, ., in, on, and, ,, at,
# Nearest to "their": its, to, for, and, from, in, his, were,
# Nearest to "not": it, that, can, was, also, did, they, be,
# Nearest to "with": and, ,, a, the, in, of, for, .,
# Nearest to "an": a, is, for, as, ,, to, with, and,
# Nearest to "a": ,, and, is, for, the, ., with, of,
# Nearest to "it": is, was, also, that, not, this, he, to,
# Nearest to ":": ``, (, '', ), or, of, ., the,
# Nearest to "``": '', or, as, (, a, ,, and, of,
# Nearest to "first": 's, the, ., of, at, in, world, by,
# Nearest to "UNK": (, ), '', and, ,, with, or, by,
# Nearest to "are": were, in, and, ., ,, the, by, is,
#
# Average loss at step 98000: 0.020828
# Nearest to "is": a, ., was, in, the, for, to, that,
# Nearest to ")": (, '', or, ,, and, ., in, the,
# Nearest to "city": 's, of, the, ., on, in, from, is,
# Nearest to "the": ., of, in, and, ,, for, 's, by,
# Nearest to "'s": the, ., of, in, on, and, ,, at,
# Nearest to "their": its, to, for, from, and, his, in, were,
# Nearest to "not": it, that, can, was, also, they, did, be,
# Nearest to "with": and, ,, a, the, in, ., of, for,
# Nearest to "an": a, is, for, as, ,, with, and, to,
# Nearest to "a": ,, and, is, for, ., the, in, of,
# Nearest to "it": is, was, also, that, not, this, he, a,
# Nearest to ":": ``, (, '', ), ., of, the, or,
# Nearest to "``": '', or, as, (, ,, and, a, .,
# Nearest to "first": 's, the, at, of, ., in, world, by,
# Nearest to "UNK": (, ), and, '', ,, with, or, from,
# Nearest to "are": were, in, ., and, ,, the, by, is,
#
# Average loss at step 100000: 0.020938
# Nearest to "is": a, ., was, the, in, for, to, of,
# Nearest to ")": (, '', or, ,, and, in, ., the,
# Nearest to "city": 's, of, ., the, on, in, from, is,
# Nearest to "the": ., of, in, and, ,, for, to, 's,
# Nearest to "'s": the, of, ., in, on, and, ,, at,
# Nearest to "their": its, to, from, for, his, and, on, were,
# Nearest to "not": it, that, can, was, also, they, be, did,
# Nearest to "with": ,, and, a, the, in, of, ., for,
# Nearest to "an": a, is, for, as, ,, with, to, in,
# Nearest to "a": ,, and, for, is, the, ., of, with,
# Nearest to "it": is, was, also, that, not, this, he, to,
# Nearest to ":": ``, (, '', ), ., or, the, of,
# Nearest to "``": '', or, as, (, ,, a, and, the,
# Nearest to "first": 's, the, ., at, of, in, world, was,
# Nearest to "UNK": (, ), ,, and, '', with, or, from,
# Nearest to "are": were, in, and, ., ,, the, is, by,
