# %% [markdown]
# # Document Embedding with Word2Vec

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
import matplotlib.cm as cm
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import nltk # standard preprocessing
import operator # sorting items in dictionary by value
#nltk.download() #tokenizers/punkt/PY3/english.pickle
from math import ceil
# Out:
# C:\Peter\Anaconda36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Dataset
# This code downloads a [dataset](http://mlg.ucd.ie/datasets/bbc.html) consisting of several BBC news articles belonging to various categories (e.g. sport, politics, etc.). Additionally the code makes sure the file has the correct size after downloading it.

# %%
url = 'http://mlg.ucd.ie/files/datasets/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('bbc-fulltext.zip', 2874078)
# Out:
# Found and verified bbc-fulltext.zip

# %% [markdown]
# ## Read Data with Preprocessing with NLTK
# Reads data as it is to a string, convert to lower-case and tokenize it using the nltk library. We have two functions `read_data` which reads `files_to_read_for_topic` files from each category and `read_test_data` which set aside 10 documents from the read documents for testing purposes.

# %%
def read_data(filename):
  """
  Extract articles up to a given threshold in a zip file as a list of words
  and pre-processes it using the nltk python library
  """
  data = []
  files_to_read_for_topic = 250
  topics = ['business','entertainment','politics','sport','tech']
  with zipfile.ZipFile(filename) as z:
    parent_dir = z.namelist()[0]
    for t in topics:
        print('\tFinished reading data for topic: ',t)
        for fi in range(1,files_to_read_for_topic):
            with z.open(parent_dir + t + '/'+ format(fi,'03d')+'.txt') as f:
                file_string = f.read().decode('latin-1')
                file_string = file_string.lower()
                file_string = nltk.word_tokenize(file_string)
                data.extend(file_string)
                
    return data

def read_test_data(filename):
  """
  Extract articles up to a given threshold in a zip file as a list of words
  and pre-processes it using the nltk python library
  """
  test_data = {}
  files_to_read_for_topic = 250
  topics = ['business','entertainment','politics','sport','tech']
  with zipfile.ZipFile(filename) as z:
    parent_dir = z.namelist()[0]
    for t in topics:
        print('\tFinished reading data for topic: ',t)
            
        for fi in np.random.randint(1,files_to_read_for_topic,(10)).tolist():
            with z.open(parent_dir + t + '/'+ format(fi,'03d')+'.txt') as f:
                file_string = f.read().decode('latin-1')
                file_string = file_string.lower()
                file_string = nltk.word_tokenize(file_string)
                test_data[t+'-'+str(fi)] = file_string
                
    return test_data

print('Processing training data...')
words = read_data(filename)
print('\nProcessing testing data...')
test_words = read_test_data(filename)

print('Example words (start): ',words[:10])
print('Example words (end): ',words[-10:])
# Out:
# Processing training data...
# 	Finished reading data for topic:  business
# 	Finished reading data for topic:  entertainment
# 	Finished reading data for topic:  politics
# 	Finished reading data for topic:  sport
# 	Finished reading data for topic:  tech
#
# Processing testing data...
# 	Finished reading data for topic:  business
# 	Finished reading data for topic:  entertainment
# 	Finished reading data for topic:  politics
# 	Finished reading data for topic:  sport
# 	Finished reading data for topic:  tech
# Example words (start):  ['ad', 'sales', 'boost', 'time', 'warner', 'profit', 'quarterly', 'profits', 'at', 'us']
# Example words (end):  ['almost', '200,000', 'people', 'are', 'registered', 'players', 'on', 'project', 'entropia', '.']

# %% [markdown]
# ## Building the Dictionaries
# Builds the following. To understand each of these elements, let us also assume the text "I like to go to school"
#
# * `dictionary`: maps a string word to an ID (e.g. {I:0, like:1, to:2, go:3, school:4})
# * `reverse_dictionary`: maps an ID to a string word (e.g. {0:I, 1:like, 2:to, 3:go, 4:school}
# * `count`: List of list of (word, frequency) elements (e.g. [(I,1),(like,1),(to,2),(go,1),(school,1)]
# * `data` : Contain the string of text we read, where string words are replaced with word IDs (e.g. [0, 1, 2, 3, 2, 4])
#
# It also introduces an additional special token `UNK` to denote rare words to are too rare to make use of.

# %%
vocabulary_size = 25000

def build_dataset(words):
  # Allocate a special token for rare words
  count = [['UNK', -1]]

  # Gets only the vocabulary_size most common words as the vocabulary
  # All the other words will be replaced with UNK token
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))


  # Create an ID for each word by giving the current length of the dictionary
  # And adding that item to the dictionary
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
    
  data = list()
  unk_count = 0
    
  # Traverse through all the text we have and produce a list
  # where each element corresponds to the ID of the word found at that index
  for word in words:
    # If word is in the dictionary use the word ID,
    # else use the ID of the special token "UNK"
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  
  # update the count variable with the number of UNK occurences
  count[0][1] = unk_count
    
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  # Make sure the dictionary is of size of the vocabulary
  assert len(dictionary) == vocabulary_size

  return data, count, dictionary, reverse_dictionary

def build_dataset_with_existing_dictionary(words, dictionary):
    '''
    Here we use this function to convert word strings to IDs
    with a given dictionary
    '''
    data = list()
    for word in words:
        if word in dictionary:
          index = dictionary[word]
        else:
          index = 0  # dictionary['UNK']
        data.append(index)
    return data

# Processining training data
data, count, dictionary, reverse_dictionary = build_dataset(words)

# Processing test data
test_data = {}
for k,v in test_words.items():
    print('Building Test Dataset for ',k,' topic')
    test_data[k] = build_dataset_with_existing_dictionary(test_words[k],dictionary)
    
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
print('test keys: ',test_data.keys())
del words  # Hint to reduce memory.
del test_words
# Out:
# Building Test Dataset for  business-59  topic
# Building Test Dataset for  business-130  topic
# Building Test Dataset for  business-114  topic
# Building Test Dataset for  business-100  topic
# Building Test Dataset for  business-169  topic
# Building Test Dataset for  business-176  topic
# Building Test Dataset for  business-1  topic
# Building Test Dataset for  business-80  topic
# Building Test Dataset for  business-180  topic
# Building Test Dataset for  business-129  topic
# Building Test Dataset for  entertainment-97  topic
# Building Test Dataset for  entertainment-208  topic
# Building Test Dataset for  entertainment-211  topic
# Building Test Dataset for  entertainment-233  topic
# Building Test Dataset for  entertainment-194  topic
# Building Test Dataset for  entertainment-159  topic
# Building Test Dataset for  entertainment-92  topic
# Building Test Dataset for  entertainment-24  topic
# Building Test Dataset for  entertainment-6  topic
# Building Test Dataset for  entertainment-192  topic
# Building Test Dataset for  politics-160  topic
# Building Test Dataset for  politics-16  topic
# Building Test Dataset for  politics-194  topic
# Building Test Dataset for  politics-61  topic
# Building Test Dataset for  politics-108  topic
# Building Test Dataset for  politics-97  topic
# Building Test Dataset for  politics-124  topic
# Building Test Dataset for  politics-189  topic
# Building Test Dataset for  politics-81  topic
# Building Test Dataset for  politics-244  topic
# Building Test Dataset for  sport-154  topic
# Building Test Dataset for  sport-82  topic
# Building Test Dataset for  sport-117  topic
# Building Test Dataset for  sport-47  topic
# Building Test Dataset for  sport-71  topic
# Building Test Dataset for  sport-138  topic
# Building Test Dataset for  sport-249  topic
# Building Test Dataset for  sport-108  topic
# Building Test Dataset for  sport-179  topic
# Building Test Dataset for  sport-153  topic
# Building Test Dataset for  tech-88  topic
# Building Test Dataset for  tech-52  topic
# Building Test Dataset for  tech-185  topic
# Building Test Dataset for  tech-119  topic
# Building Test Dataset for  tech-14  topic
# Building Test Dataset for  tech-199  topic
# Building Test Dataset for  tech-138  topic
# Building Test Dataset for  tech-75  topic
# Building Test Dataset for  tech-109  topic
# Building Test Dataset for  tech-166  topic
# Most common words (+UNK) [['UNK', 912], ('the', 28312), ('.', 21345), (',', 18517), ('to', 13509)]
# Sample data [4364, 170, 702, 79, 2435, 955, 4365, 533, 25, 54]
# test keys:  dict_keys(['business-59', 'business-130', 'business-114', 'business-100', 'business-169', 'business-176', 'business-1', 'business-80', 'business-180', 'business-129', 'entertainment-97', 'entertainment-208', 'entertainment-211', 'entertainment-233', 'entertainment-194', 'entertainment-159', 'entertainment-92', 'entertainment-24', 'entertainment-6', 'entertainment-192', 'politics-160', 'politics-16', 'politics-194', 'politics-61', 'politics-108', 'politics-97', 'politics-124', 'politics-189', 'politics-81', 'politics-244', 'sport-154', 'sport-82', 'sport-117', 'sport-47', 'sport-71', 'sport-138', 'sport-249', 'sport-108', 'sport-179', 'sport-153', 'tech-88', 'tech-52', 'tech-185', 'tech-119', 'tech-14', 'tech-199', 'tech-138', 'tech-75', 'tech-109', 'tech-166'])

# %% [markdown]
# ## Generating Batches of Data for Skip-Gram
# Generates a batch or target words (`batch`) and a batch of corresponding context words (`labels`). It reads `2*window_size+1` words at a time (called a `span`) and create `2*window_size` datapoints in a single span. The function continue in this manner until `batch_size` datapoints are created. Everytime we reach the end of the word sequence, we start from beginning.

# %%
data_index = 0

def generate_batch(data, batch_size, window_size):
    # data_index is updated by 1 everytime we read a data point
    global data_index
    
    # span defines the total window size, where
    # data we consider at an instance looks as follows. 
    # [ skip_window target skip_window ]
    span = 2 * window_size + 1
    
    # two numpy arras to hold target words (batch)
    # and context words (labels)
    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
    # The buffer holds the data contained within the span
    buffer = collections.deque(maxlen=span)

    # Fill the buffer and update the data_index
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # This is the number of context words we sample for a single target word
    num_samples = 2*window_size 

    # We break the batch reading into two for loops
    # The inner for loop fills in the batch and labels with 
    # num_samples data points using data contained withing the span
    # The outper for loop repeat this for batch_size//num_samples times
    # to produce a full batch
    for i in range(batch_size // num_samples):
      k=0
      # avoid the target word itself as a prediction
      # fill in batch and label numpy arrays
      for j in list(range(window_size))+list(range(window_size+1,2*window_size+1)):
        batch[i * num_samples + k] = buffer[window_size]
        labels[i * num_samples + k, 0] = buffer[j]
        k += 1 
    
      # Everytime we read num_samples data points,
      # we have created the maximum number of datapoints possible
      # withing a single span, so we need to move the span by 1
      # to create a fresh new span
      buffer.append(data[data_index])
      data_index = (data_index + 1) % len(data)

    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels

for window_size in [1,2]:
    data_index = 0
    batch, labels = generate_batch(data, batch_size=8, window_size=window_size)
    print('\nwith window_size = %d:' % (window_size))
    print('    batch:', [[reverse_dictionary[bii] for bii in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# with window_size = 1:
#     batch: [['sales', 'sales'], ['sales', 'sales'], ['boost', 'boost'], ['boost', 'boost'], ['time', 'time'], ['time', 'time'], ['warner', 'warner'], ['warner', 'warner']]
#     labels: ['ad', 'boost', 'sales', 'time', 'boost', 'warner', 'time', 'profit']
#
# with window_size = 2:
#     batch: [['boost', 'boost', 'boost', 'boost'], ['boost', 'boost', 'boost', 'boost'], ['boost', 'boost', 'boost', 'boost'], ['boost', 'boost', 'boost', 'boost'], ['time', 'time', 'time', 'time'], ['time', 'time', 'time', 'time'], ['time', 'time', 'time', 'time'], ['time', 'time', 'time', 'time']]
#     labels: ['ad', 'sales', 'time', 'warner', 'sales', 'boost', 'warner', 'profit']

# %%
test_data_index = 0

def generate_test_batch(data, batch_size):
    '''
    Generate a batch of data from the test data
    This is used to compute the document embedding
    by taking the average of all the words in a document
    '''
    global test_data_index

    batch = np.ndarray(shape=(batch_size,), dtype=np.int32)
    # Get words starting from index 0 to span
    for bi in range(batch_size):
        batch[bi] = data[test_data_index]
        test_data_index = (test_data_index + 1) % len(data)

    return batch

test_data_index = 0
test_batch = generate_test_batch(test_data[list(test_data.keys())[0]], batch_size=8)
print('\nwith window_size = %d:' % (window_size))
print('    labels:', [reverse_dictionary[li] for li in test_batch.reshape(8)])
# Out:
# with window_size = 2:
#     labels: ['worldcom', 'ex-boss', 'launches', 'defence', 'lawyers', 'defending', 'former', 'worldcom']

# %% [markdown]
# # CBOW Algorithm

# %% [markdown]
# ### Defining Hyperparameters
#
# Here we define several hyperparameters including `batch_size` (amount of samples in a single batch) `embedding_size` (size of embedding vectors) `window_size` (context window size).

# %%
batch_size = 128 # Data points in a single batch
embedding_size = 128 # Dimension of the embedding vector.
window_size = 4 # How many words to consider left and right.

# We pick a random validation set to sample nearest neighbors
valid_size = 16 # Random set of words to evaluate similarity on.
# We sample valid datapoints randomly from a large window without always being deterministic
valid_window = 50

# When selecting valid examples, we select some of the most frequent words as well as
# some moderately rare words as well
valid_examples = np.array(random.sample(range(valid_window), valid_size))
valid_examples = np.append(valid_examples,random.sample(range(1000, 1000+valid_window), valid_size),axis=0)

num_sampled = 32 # Number of negative examples to sample.

# %% [markdown]
# ### Defining Inputs and Outputs
#
# Here we define placeholders for feeding in training inputs and outputs (each of size `batch_size`) and a constant tensor to contain validation examples.

# %%
tf.reset_default_graph()

# Training input data (target word IDs).
train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*window_size])

# Training input label data (context word IDs)
train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])

# Validation input data, we don't need a placeholder
# as we have already defined the IDs of the words selected
# as validation data used to evaluate the word vectors
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# Test data. This is used to compute the document embeddings by averaging
# word embeddings of a given document
test_labels = tf.placeholder(tf.int32, shape=[batch_size],name='test_dataset')

# %% [markdown]
# ### Defining Model Parameters and Other Variables
# We now define several TensorFlow variables such as an embedding layer (`embeddings`) and neural network parameters (`softmax_weights` and `softmax_biases`)

# %%
# Variables.
# embedding, vector for each word in the vocabulary
embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0,dtype=tf.float32))
softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                     stddev=1.0 / math.sqrt(embedding_size),dtype=tf.float32))
softmax_biases = tf.Variable(tf.zeros([vocabulary_size],dtype=tf.float32))

# %% [markdown]
# ### Defining the Model Computations
#
# We first defing a lookup function to fetch the corresponding embedding vectors for a set of given inputs. With that, we define negative sampling loss function `tf.nn.sampled_softmax_loss` which takes in the embedding vectors and previously defined neural network parameters.

# %%
# Used to compute document embeddings by averaging all the word vectors of a 
# given batch of test data
mean_batch_embedding = tf.reduce_mean(tf.nn.embedding_lookup(embeddings,test_labels),axis=0)
    
# Model.
# Look up embeddings for all the context words of the inputs.
# Then compute a tensor by staking embeddings of all context words
stacked_embedings = None
print('Defining %d embedding lookups representing each word in the context'%(2*window_size))
for i in range(2*window_size):
    embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])        
    x_size,y_size = embedding_i.get_shape().as_list()
    if stacked_embedings is None:
        stacked_embedings = tf.reshape(embedding_i,[x_size,y_size,1])
    else:
        stacked_embedings = tf.concat(axis=2,values=[stacked_embedings,tf.reshape(embedding_i,[x_size,y_size,1])])

# Make sure the staked embeddings have 2*window_size columns
assert stacked_embedings.get_shape().as_list()[2]==2*window_size
print("Stacked embedding size: %s"%stacked_embedings.get_shape().as_list())

# Compute mean embeddings by taking the mean of the tensor containing the stack of embeddings
mean_embeddings =  tf.reduce_mean(stacked_embedings,2,keepdims=False)
print("Reduced mean embedding size: %s"%mean_embeddings.get_shape().as_list())
# Out:
# Defining 8 embedding lookups representing each word in the context
# Stacked embedding size: [128, 128, 8]
# Reduced mean embedding size: [128, 128]

# %% [markdown]
# ## Computing Loss
# Loss computation using sampled softmax

# %%
# Compute the softmax loss, using a sample of the negative labels each time.
# inputs are embeddings of the train words
# with this loss we optimize weights, biases, embeddings

# If you see the warning
# WARNING:tensorflow:From c:\...\lib\site-packages\tensorflow\python\ops\nn_impl.py:1346: 
# softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and 
# will be removed in a future version.
# You can ignore this. This caused by the internally used softmax_cross_entropy_with_logits function
loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=mean_embeddings,
                           labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

# %% [markdown]
# ### Calculating Word Similarities
# We calculate the similarity between two given words in terms of the cosine distance. To do this efficiently we use matrix operations to do so, as shown below.

# %%
# Compute the similarity between minibatch examples and all embeddings.
# We use the cosine distance:
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %% [markdown]
# ### Model Parameter Optimizer
#
# We then define a constant learning rate and an optimizer which uses the Adagrad method. Feel free to experiment with other optimizers listed [here](https://www.tensorflow.org/api_guides/python/train).

# %%
# Optimizer. Adagrad optimizers has learning rates assigned to individual parameters
optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

# %% [markdown]
# ## Running the CBOW Algorithm on Document Data
#
# Here we run the CBOW algorithm we defined above. Specifically, we first initialize variables, and then train the algorithm for many steps (`num_steps`). And every few steps we evaluate the algorithm on a fixed validation set and print out the words that appear to be closest for a given set of words.

# %%
num_steps = 100001
cbow_loss = []

config=tf.ConfigProto(allow_soft_placement=True)
# This is an important setting and with limited GPU memory,
# not using this option might lead to the following error.
# InternalError (see above for traceback): Blas GEMM launch failed : ...
config.gpu_options.allow_growth = True

with tf.Session(config=config) as session:
    
    # Initialize the variables in the graph
    tf.global_variables_initializer().run()
    print('Initialized')
    
    average_loss = 0
    
    # Train the Word2vec model for num_step iterations
    for step in range(num_steps):
        
        # Generate a single batch of data
        batch_data, batch_labels = generate_batch(data, batch_size, window_size)
        
        # Populate the feed_dict and run the optimizer (minimize loss)
        # and compute the loss
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        
        # Update the average loss variable
        average_loss += l
        
        if (step+1) % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step+1, average_loss))
            cbow_loss.append(average_loss)
            average_loss = 0
        
        # Evaluating validation set word similarities
        if (step+1) % 10000 == 0:
            sim = similarity.eval()
            # Here we compute the top_k closest words for a given validation word
            # in terms of the cosine distance
            # We do this for all the words in the validation set
            # Note: This is an expensive step
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    
    # Computing test documents embeddings by averaging word embeddings
    
    # We take batch_size*num_test_steps words from each document
    # to compute document embeddings
    num_test_steps = 100
    
    # Store document embeddings
    # {document_id:embedding} format
    document_embeddings = {}
    print('Testing Phase (Compute document embeddings)')
    
    # For each test document compute document embeddings
    '''
     1.傳入已產生為dict的test_data，每個k(key)為測試項(e.g. tech-56)
       的值test_data[k]
     2.傳入generate_test_batch產生batch_size大小的test_batch_labels
      （字典字的index）
     3.傳入mean_batch_embedding藉由tf.nn.embedding_lookup按已訓練的embeddings
       查表求每column的embedding vector(axis=0)的平均得batch_mean
       （注意,不是每個字(axis=1)的平均）
     4.傳入記錄在topic_mean_batch_embeddings（以axis=0紀錄）
     5.重複1~4步驟num_test_steps次後再取平均放document_embeddings
     6.再改變k再重複1~5步驟記錄不同topic的document_embeddings
            '''
    for k,v in test_data.items():
        print('\tCalculating mean embedding for document ',k,' with ', num_test_steps, ' steps.')
        test_data_index = 0
        topic_mean_batch_embeddings = np.empty((num_test_steps,embedding_size),dtype=np.float32)
        
        # keep averaging mean word embeddings obtained for each step
        for test_step in range(num_test_steps):
            test_batch_labels = generate_test_batch(test_data[k],batch_size)
            batch_mean = session.run(mean_batch_embedding,feed_dict={test_labels:test_batch_labels})
            topic_mean_batch_embeddings[test_step,:] = batch_mean
        document_embeddings[k] = np.mean(topic_mean_batch_embeddings,axis=0)
# Out:
# Initialized
# Average loss at step 2000: 3.908853
# Average loss at step 4000: 3.566954
# Average loss at step 6000: 3.543199
# Average loss at step 8000: 3.539177
# Average loss at step 10000: 3.471064
# Nearest to on: 's, barcelona, moniker, harley, aoife, %, robbie, in,
# Nearest to from: and, in, for, -, with, purchased, wiedersehen, iceland,
# Nearest to that: fuqua, unfortunate, to, pending, grace, not, variation, sportswear,
# Nearest to were: are, atrium, restricting, cinemanow, hacked, breathtaking, â£1.3, 'had,
# Nearest to was: is, had, ,, would, 4.75, 65-year, destinations, flouted,
# Nearest to will: would, to, is, barcelona, seasonality, should, are, title-winning,
# Nearest to not: consultant, citizens, anyone, larribeau, still, that, spur, riot,
# Nearest to at: under-21s, samples, thie, 21.00, in, millionaires, investments, severe,
# Nearest to and: for, -, ,, from, ., with, by, in,
# Nearest to '': he, :, doncaster, holdings, economy, paint, abusing, said,
# Nearest to said: parliaments, simonetti, added, meseret, 65-year, says, also, jamaican,
# Nearest to be: mean, it, w800, 1.4850, one-hundreth, mortgage-style, tub, prowess,
# Nearest to 's: the, his, on, apollo, ,, market, jocelyn, pressures,
# Nearest to people: xboxes, research, braille, armand, 42.7, patrick, booming, 49.74,
# Nearest to his: 's, the, wandsworth, misleads, scientists, messenger, traore, a,
# Nearest to which: unlawful, compiling, help, rang, quote, indrawati, assure, grubby,
# Average loss at step 12000: 3.418769
# Average loss at step 14000: 3.385181
# Average loss at step 16000: 3.416366
# Average loss at step 18000: 3.499475
# Average loss at step 20000: 3.411496
# Nearest to on: ear, qantas, dissenting, from, in, eye-popping, cinematic, â£8.4m,
# Nearest to from: in, sky+, with, blatantly, which, into, 80., on,
# Nearest to that: but, also, not, there, ., it, if, paion,
# Nearest to were: are, receiving, is, ciara, glow, duties, exceeding, other,
# Nearest to was: is, has, had, encountered, acts, condoleezza, brought, right-footed,
# Nearest to will: would, to, could, can, should, is, liberalisation, 77,000.,
# Nearest to not: n't, it, they, that, i, but, trailblazer, what,
# Nearest to at: â£190m, jamaican, seminal, paul, shares, surpluses, smith, threatening,
# Nearest to and: adware, which, comprising, 140,000, mcconnell, six-part, stature, laggard,
# Nearest to '': mr, he, said, :, 0.3, ,, hedging, soviets,
# Nearest to said: added, '', says, he, mr, qc, but, ``,
# Nearest to be: selecting, have, take, forgiven, probably, clear, come, eligible,
# Nearest to 's: has, invasion, is, represents, an, f, edgar, 70s,
# Nearest to people: do, 42.7, braille, did, choreographers, functioned, xboxes, stays,
# Nearest to his: its, burnout, acclaimed, ferried, rover, seated, 25., buoyant,
# Nearest to which: from, and, -, new, cashed, by, makers, innovative,
# Average loss at step 22000: 3.366647
# Average loss at step 24000: 3.238003
# Average loss at step 26000: 3.247971
# Average loss at step 28000: 3.261595
# Average loss at step 30000: 3.288824
# Nearest to on: moniker, in, after, for, rotterdam, debts, and, freeze,
# Nearest to from: with, and, ', which, after, re-examined, at, in,
# Nearest to that: but, about, divisions, there, it, ., ,, paired,
# Nearest to were: are, was, cinemanow, tensions, restricting, exceeding, is, have,
# Nearest to was: were, is, has, had, boe, '', edonkey, 's,
# Nearest to will: would, should, can, could, is, to, and, speakers,
# Nearest to not: n't, it, consultant, 850bn, boast, that, i, if,
# Nearest to at: with, waller, interconnection, from, sant, hutton, â£300, of,
# Nearest to and: ,, from, for, -, of, to, with, which,
# Nearest to '': :, he, is, missions, said, interrogated, was, 's,
# Nearest to said: added, told, says, mr, vies, synergies, '', ``,
# Nearest to be: take, allow, have, is, gray, are, forcible, their,
# Nearest to 's: the, brown, perreira, his, mop, '', utgoff, was,
# Nearest to people: they, their, are, braille, money, cables, who, intervoice,
# Nearest to his: an, a, mr, 's, traore, their, her, 1.3187,
# Nearest to which: who, and, quote, from, help, 4in, with, non-existent,
# Average loss at step 32000: 3.245212
# Average loss at step 34000: 3.160936
# Average loss at step 36000: 3.175313
# Average loss at step 38000: 3.285335
# Average loss at step 40000: 3.266812
# Nearest to on: in, cinematic, from, ear, norvasc, uk-listed, into, to,
# Nearest to from: after, into, in, cutting-edge, on, or, with, settle,
# Nearest to that: ., also, which, not, it, by, ,, to,
# Nearest to were: are, was, had, is, mahfouz, icons, receiving, sundance,
# Nearest to was: is, were, has, 's, are, had, would, gigapixel,
# Nearest to will: would, can, should, could, is, payouts, to, transparency,
# Nearest to not: n't, that, still, it, if, riot, reaction, how,
# Nearest to at: in, for, of, poole, from, seminal, threatening, smith,
# Nearest to and: -, for, which, ,, but, such, as, like,
# Nearest to '': he, mr, ,, :, ``, said, bbc1, mull,
# Nearest to said: added, says, told, but, mr, '', ,, he,
# Nearest to be: take, help, also, allow, which, come, forgiven, see,
# Nearest to 's: is, was, its, the, in, invasion, build-up, stephenson,
# Nearest to people: their, money, they, functioned, we, those, braille, off-load,
# Nearest to his: its, djhone, alarms, their, a, 'human, burnout, clashed,
# Nearest to which: that, and, also, already, to, who, be, it,
# Average loss at step 42000: 3.244072
# Average loss at step 44000: 3.181285
# Average loss at step 46000: 3.178414
# Average loss at step 48000: 3.130651
# Average loss at step 50000: 3.201541
# Nearest to on: and, ,, from, the, in, after, overshoot, fiancailles,
# Nearest to from: and, in, on, of, through, statistic, profanities, -,
# Nearest to that: not, it, but, what, there, ``, also, be,
# Nearest to were: are, was, had, tensions, be, hacked, by, time-consuming,
# Nearest to was: is, were, has, had, ,, be, exhausted, par,
# Nearest to will: can, would, should, could, fipresci, may, to, differently,
# Nearest to not: that, n't, to, if, be, they, prioritised, also,
# Nearest to at: interconnection, panlogic, by, in, waller, blair-era, obtained, on,
# Nearest to and: ,, in, to, the, from, of, for, .,
# Nearest to '': behaviour, heartened, nettles, the, radios, addition, :, â£22bn,
# Nearest to said: added, told, but, says, saying, accountant, bogdanchikov, parliaments,
# Nearest to be: not, mean, have, that, it, take, was, see,
# Nearest to 's: â£49m, ,, dvb-h, the, programme, apollo, ., 1.3187,
# Nearest to people: they, all, those, visualised, money, rubicam, braille, signal,
# Nearest to his: her, mr, misrepresent, their, he, jaguar, clearing, traore,
# Nearest to which: compiling, who, rural, haile, funkier, leeks, spamming, grace,
# Average loss at step 52000: 3.175344
# Average loss at step 54000: 3.150357
# Average loss at step 56000: 3.036428
# Average loss at step 58000: 3.148045
# Average loss at step 60000: 3.202667
# Nearest to on: in, compromising, roti, from, after, interoperable, into, average,
# Nearest to from: te, 80., blatantly, on, through, splitting, infected, or,
# Nearest to that: but, ., not, also, if, mcwhirter, claudio, what,
# Nearest to were: are, was, had, receiving, they, mahfouz, postgraduate, â£131,961,
# Nearest to was: is, were, has, had, 's, sang, are, forbidden,
# Nearest to will: would, could, can, should, payouts, 8.08, uncovered, is,
# Nearest to not: n't, if, still, that, they, afford, edelman, riot,
# Nearest to at: in, for, of, â£56m, tall, turnout, 777, from,
# Nearest to and: ,, such, ferrari, as, but, bursary, authenticate, megastores,
# Nearest to '': he, mr, :, said, battleground, 's, ``, endemol,
# Nearest to said: added, says, qc, mr, however, '', told, provincial,
# Nearest to be: take, make, see, supplying, mean, headingley, gray, forgiven,
# Nearest to 's: is, its, the, was, has, human-robot, build-up, '',
# Nearest to people: those, money, they, vinyl, redirection, all, net, viewers,
# Nearest to his: niven, senderos, its, a, djhone, grandchild, their, him,
# Nearest to which: ruined, who, across, weekly, funkier, proponents, rolls, snyder,
# Average loss at step 62000: 3.162945
# Average loss at step 64000: 3.164802
# Average loss at step 66000: 3.094030
# Average loss at step 68000: 3.110086
# Average loss at step 70000: 3.111284
# Nearest to on: in, overshoot, stops, gateshead, bloc, ramp, cosby, subtle,
# Nearest to from: after, and, soundtrack, strongest, statistic, â£10.5bn, relishing, talbot,
# Nearest to that: it, but, 1.4850, ., numerous, also, ``, there,
# Nearest to were: are, was, had, â£131,961, receiving, beard, is, long-standing,
# Nearest to was: were, is, had, has, 's, be, exhausted, '',
# Nearest to will: would, should, can, could, may, crossroads, differently, must,
# Nearest to not: n't, 153,000, they, whether, that, swear, thought-out, reignite,
# Nearest to at: interconnection, drafting, 25,000, super-casino, waller, in, by, mukherjee,
# Nearest to and: ,, in, ., to, the, for, of, 9ins,
# Nearest to '': said, :, ``, was, he, pile-up, metlife, moffat,
# Nearest to said: added, told, says, '', think, he, saying, however,
# Nearest to be: have, see, was, tillen, disclosed, gray, campaigner, obvious,
# Nearest to 's: the, was, is, ``, ,, overlooked, said, wandsworth,
# Nearest to people: those, more, money, we, earring, they, continents, burdens,
# Nearest to his: their, him, suites, remedy, jaguar, mr, her, misleads,
# Nearest to which: woodsman, incurred, compiling, 39-year-old, haile, ruined, who, funkier,
# Average loss at step 72000: 3.155297
# Average loss at step 74000: 3.105774
# Average loss at step 76000: 3.019237
# Average loss at step 78000: 3.010874
# Average loss at step 80000: 3.183825
# Nearest to on: into, lightweight, by, moniker, for, aoife, from, ear,
# Nearest to from: after, as, ,, through, hush, in, for, 's,
# Nearest to that: it, what, by, not, but, also, only, 20m,
# Nearest to were: are, was, had, â£131,961, they, icons, 're, is,
# Nearest to was: is, were, 's, has, had, are, would, boe,
# Nearest to will: would, can, should, could, inventions, to, is, payouts,
# Nearest to not: n't, if, manoeuvre, that, you, they, paid-for, countering,
# Nearest to at: in, logan, first, for, threatening, caravaggio, harbour, blair-era,
# Nearest to and: ,, to, ., the, but, in, of, authenticate,
# Nearest to '': he, but, 's, :, said, bbc1, if, has,
# Nearest to said: added, told, but, says, amazon.co.uk, ,, '', arabs,
# Nearest to be: correcting, mean, see, make, learn, take, allow, supplying,
# Nearest to 's: is, was, the, '', a, but, has, its,
# Nearest to people: they, those, money, lucky, who, duffer, we, net,
# Nearest to his: him, seated, misleads, fiszman, maciej, burnout, in-game, a,
# Nearest to which: telephone, who, nice, downloading, on-demand, unlawful, romped, textiles,
# Average loss at step 82000: 3.116419
# Average loss at step 84000: 3.145129
# Average loss at step 86000: 3.067868
# Average loss at step 88000: 3.097671
# Average loss at step 90000: 3.030067
# Nearest to on: in, overshoot, afternoon, bloc, meo, ceremony, tore, huts,
# Nearest to from: after, supplementary, in, including, and, off, 2.4, through,
# Nearest to that: but, ., it, ``, what, also, there, enjoying,
# Nearest to were: are, was, had, contraception, did, 5km, icons, long-standing,
# Nearest to was: is, were, had, has, 80m, galvanize, exhausted, she,
# Nearest to will: would, can, should, could, may, to, 40-1, dictatorship,
# Nearest to not: n't, afford, because, if, reignite, but, pilots, countering,
# Nearest to at: phasing, first, parlour, salaam, headache, where, tampa, obtained,
# Nearest to and: ,, ., of, 9ins, soundtrack, with, beardsley, 's,
# Nearest to '': :, ', ``, we, however, imelda, he, offline,
# Nearest to said: added, told, says, ``, also, however, grieve, believe,
# Nearest to be: see, correcting, gray, tillen, trailers, allyn, ultra, make,
# Nearest to 's: is, and, sme, lexus, was, knowing, were, will,
# Nearest to people: those, more, they, money, braille, 21.58, undeniable, nominees,
# Nearest to his: their, the, a, her, him, he, traore, acclaimed,
# Nearest to which: who, funkier, jerry, woodsman, compiling, that, waypoints, evictions,
# Average loss at step 92000: 3.114496
# Average loss at step 94000: 3.094289
# Average loss at step 96000: 3.038908
# Average loss at step 98000: 2.953099
# Average loss at step 100000: 3.076137
# Nearest to on: from, to, 's, by, diplomacy, in, yale, un-named,
# Nearest to from: on, after, and, into, as, by, in, 7.64secs,
# Nearest to that: which, and, the, also, to, ., it, ,,
# Nearest to were: are, was, people, icons, have, be, â£131,961, is,
# Nearest to was: is, 's, were, are, has, etchi, be, vinod,
# Nearest to will: would, can, could, should, to, is, 8.08, inventions,
# Nearest to not: n't, like, if, countering, that, afford, to, pirated,
# Nearest to at: in, poole, caravaggio, textbooks, striders, coincidental, dashing, sao,
# Nearest to and: ,, to, ., that, which, but, in, of,
# Nearest to '': ,, he, 's, said, milanesi, is, the, :,
# Nearest to said: added, told, qc, '', amazon.co.uk, macworld, withdrawn, filtering,
# Nearest to be: make, is, mean, also, were, -, donate, elephants,
# Nearest to 's: was, is, a, the, on, '', its, refuelling,
# Nearest to people: those, they, were, more, we, users, net, money,
# Nearest to his: him, in-game, their, spaghetti, seated, one-day, victory, penny,
# Nearest to which: that, and, or, who, the, non-existent, downloading, be,
# Testing Phase (Compute document embeddings)
# 	Calculating mean embedding for document  business-59  with  100  steps.
# 	Calculating mean embedding for document  business-130  with  100  steps.
# 	Calculating mean embedding for document  business-114  with  100  steps.
# 	Calculating mean embedding for document  business-100  with  100  steps.
# 	Calculating mean embedding for document  business-169  with  100  steps.
# 	Calculating mean embedding for document  business-176  with  100  steps.
# 	Calculating mean embedding for document  business-1  with  100  steps.
# 	Calculating mean embedding for document  business-80  with  100  steps.
# 	Calculating mean embedding for document  business-180  with  100  steps.
# 	Calculating mean embedding for document  business-129  with  100  steps.
# 	Calculating mean embedding for document  entertainment-97  with  100  steps.
# 	Calculating mean embedding for document  entertainment-208  with  100  steps.
# 	Calculating mean embedding for document  entertainment-211  with  100  steps.
# 	Calculating mean embedding for document  entertainment-233  with  100  steps.
# 	Calculating mean embedding for document  entertainment-194  with  100  steps.
# 	Calculating mean embedding for document  entertainment-159  with  100  steps.
# 	Calculating mean embedding for document  entertainment-92  with  100  steps.
# 	Calculating mean embedding for document  entertainment-24  with  100  steps.
# 	Calculating mean embedding for document  entertainment-6  with  100  steps.
# 	Calculating mean embedding for document  entertainment-192  with  100  steps.
# 	Calculating mean embedding for document  politics-160  with  100  steps.
# 	Calculating mean embedding for document  politics-16  with  100  steps.
# 	Calculating mean embedding for document  politics-194  with  100  steps.
# 	Calculating mean embedding for document  politics-61  with  100  steps.
# 	Calculating mean embedding for document  politics-108  with  100  steps.
# 	Calculating mean embedding for document  politics-97  with  100  steps.
# 	Calculating mean embedding for document  politics-124  with  100  steps.
# 	Calculating mean embedding for document  politics-189  with  100  steps.
# 	Calculating mean embedding for document  politics-81  with  100  steps.
# 	Calculating mean embedding for document  politics-244  with  100  steps.
# 	Calculating mean embedding for document  sport-154  with  100  steps.
# 	Calculating mean embedding for document  sport-82  with  100  steps.
# 	Calculating mean embedding for document  sport-117  with  100  steps.
# 	Calculating mean embedding for document  sport-47  with  100  steps.
# 	Calculating mean embedding for document  sport-71  with  100  steps.
# 	Calculating mean embedding for document  sport-138  with  100  steps.
# 	Calculating mean embedding for document  sport-249  with  100  steps.
# 	Calculating mean embedding for document  sport-108  with  100  steps.
# 	Calculating mean embedding for document  sport-179  with  100  steps.
# 	Calculating mean embedding for document  sport-153  with  100  steps.
# 	Calculating mean embedding for document  tech-88  with  100  steps.
# 	Calculating mean embedding for document  tech-52  with  100  steps.
# 	Calculating mean embedding for document  tech-185  with  100  steps.
# 	Calculating mean embedding for document  tech-119  with  100  steps.
# 	Calculating mean embedding for document  tech-14  with  100  steps.
# 	Calculating mean embedding for document  tech-199  with  100  steps.
# 	Calculating mean embedding for document  tech-138  with  100  steps.
# 	Calculating mean embedding for document  tech-75  with  100  steps.
# 	Calculating mean embedding for document  tech-109  with  100  steps.
# 	Calculating mean embedding for document  tech-166  with  100  steps.

# %% [markdown]
# ## Visualizing documents with t-SNE

# %% [markdown]
# ### Defining a t-SNE and fitting data
# Here we define a t-SNE with its parameters and fit the learned embeddings to visualize them on a two dimensional surface.

# %%
# Number of data points to visualize
num_points = 1000 

# Create a t-SNE object
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)

print('Fitting embeddings to T-SNE')
# get the T-SNE manifold
doc_ids, doc_embeddings = zip(*document_embeddings.items())
two_d_embeddings = tsne.fit_transform(doc_embeddings)
print('\tDone')
# Out:
# Fitting embeddings to T-SNE
# 	Done

# %% [markdown]
# ### Plotting the t-SNE results
# After fitting the embeddings to the t-SNE, we can visualize the results with Matplotlib library.

# %%
def plot(embeddings, labels):
  
  n_clusters = 5 # number of clusters
    
  # automatically build a discrete set of colors, each for cluster
  cmap = cm.get_cmap("Spectral")
  label_colors = [cmap(float(i) /n_clusters) for i in range(n_clusters)]
  label_markers = ['o','^','d','s','x']
  # make sure the number of document embeddings is same as
  # point labels provided
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  
  pylab.figure(figsize=(15,15))  # in inches

  def get_label_id_from_key(key):
    '''
    We assign each different category a cluster_id
    This is assigned based on what is contained in the point label
    Not the actual clustering results
    '''
    if 'business' in key:
        return 0
    elif 'entertainment' in key:
        return 1
    elif 'politics' in key:
        return 2
    elif 'sport' in key:
        return 3
    elif 'tech' in key:
        return 4
            
  # Plot all the document embeddings and their corresponding words
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]  #傳入經TSNE後的2D embedding值作為座標 x, y值
    pylab.scatter(x, y, c=label_colors[get_label_id_from_key(label)],s=50,
                  marker=label_markers[get_label_id_from_key(label)])    
    
    # Annotate each point on the scatter plot
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom',fontsize=16)
  
  # Set plot title
  pylab.title('Document Embeddings visualized with t-SNE',fontsize=24)
  
  # Use for saving the figure if needed
  pylab.savefig('document_embeddings.png')
  pylab.show()

# Run the plotting function
plot(two_d_embeddings, doc_ids)

# %% [markdown]
# ## Perform Document Classification
#
# Here we first cluster the document embeddings by means of K-means. K-means is a popular and simple clustering algorithm. Then we will list what is contained in each cluster. Each cluster should roughly contain documents belonging to a single category. You can use the same information to classify an unseen document using the following steps.
# 1. Compute the document embeddings for test document
# 2. Compute K-means using all the previous documents + the new document
# 3. Label the new test document to be of the category most of it's neighbors belong to

# %%
# Create and fit K-means
kmeans = KMeans(n_clusters=5, random_state=43643, max_iter=10000, n_init=100, algorithm='elkan')
kmeans.fit(np.array(list(document_embeddings.values())))

# Compute items fallen within each cluster
'''kmeans.labels_是cluste完的label值，此處為0~4，再把document_embeddings
   的key值（內含test文件代號，e.g. tech-56）與此label值zip起來，
   再依label值把此key值分類集合(document_classes[lbl] = [inp])並顯示'''
document_classes = {}
for inp, lbl in zip(list(document_embeddings.keys()), kmeans.labels_):
    if lbl not in document_classes:
        document_classes[lbl] = [inp] #要用[inp]形成list才能用append
    else:
        document_classes[lbl].append(inp)
for k,v in document_classes.items():    
    print('\nDocuments in Cluster ',k)
    print('\t',v)
# Out:
# Documents in Cluster  4
# 	 ['business-59', 'business-114', 'business-100']
#
# Documents in Cluster  2
# 	 ['business-130', 'business-169', 'business-176', 'business-1', 'business-180', 'business-129', 'entertainment-211', 'entertainment-194', 'entertainment-159', 'tech-88', 'tech-52', 'tech-185', 'tech-119', 'tech-138', 'tech-75', 'tech-109', 'tech-166']
#
# Documents in Cluster  0
# 	 ['business-80', 'entertainment-208', 'entertainment-192', 'politics-160', 'politics-16', 'politics-194', 'politics-61', 'politics-108', 'politics-97', 'politics-124', 'politics-189', 'politics-81', 'politics-244', 'sport-82', 'sport-47', 'tech-14', 'tech-199']
#
# Documents in Cluster  1
# 	 ['entertainment-97', 'entertainment-233', 'entertainment-92', 'entertainment-24', 'entertainment-6']
#
# Documents in Cluster  3
# 	 ['sport-154', 'sport-117', 'sport-71', 'sport-138', 'sport-249', 'sport-108', 'sport-179', 'sport-153']
